# %% [markdown]
# # Assertion RLA

# %% [markdown]
# **From 20 October 2022, major re-write and restructuring of the code and classes.**
#
# **From 18 May 2022, consistent sampling seems to be working.**
#
# **From 1 April 2022, integrating alpha_mart, p_history, and other features.**
#
# **From 24 October 2021, dev version implementing consistent sampling to target smaller contests.**
#
# ## Overview of the assertion audit tool
#
# The tool requires as input:
#
# + audit-specific and contest-specific parameters, such as
#     - whether to sample with or without replacement
#     - the name of the risk function to use, and any parameters it requires
#     - a risk limit for each contest to be audited
#     - the social choice function for each contest, including the number of winners
#     - candidate identifiers for each contest
#     - reported winner(s) for each contest
#     - an upper bound on the number of ballot cards that contain each contest
#     - an upper bound on the total number of cards across all contests
#     - whether to use card style information to target sampling
# + a ballot manifest (see below)
# + a random seed
# + a file of cast vote records (for ballot-comparison audits)
# + reported vote tallies for for each contest (for ballot-polling audits of plurality, supermajority, and approval social choice functions)
# + json files of assertions for IRV contests (one file per IRV contest)
# + human reading of voter intent from the paper cards selected for audit
#
# `use_style` controls whether the sample is drawn from all cards (`use_style == False`) or card style information is used
# to target the cards that purport to contain each contest (`use_style == True`).
# In the current implementation, card style information is inferred from cast-vote records, with additional 'phantom' CVRs if there could be more cards that contain a contest than is accounted for in the CVRs.
# Errors in the card style information are treated conservatively using the  "phantoms-to-evil-zombies" (~2EZ) approach ([Banuelos & Stark, 2012](https://arxiv.org/abs/1207.3413)) so that the risk limit remains valid, even if the CVRs misrepresent
# which cards contain which contests.
#
# The two ways of sampling are treated differently.
# If the sample is to be drawn only from cards that--according to the CVR--contain a particular contest, and a sampled card turns out not to
# contain that contest, that is considered a discrepancy, dealt with using the ~2EZ approach.
# It is assumed that every CVR corresponds to a card in the manifest, but there might
# be cards cast in the contest for which there is no corresponding CVR. In that case,
# phantom CVRs are created to ensure that the audit is still truly risk-limiting.
#
# Given an independent (i.e., not relying on the voting system) upper bound on the number of cards that contain the contest, if the number of CVRs that contain the contest does not exceed that bound, we can sample from paper purported to contain the contest and use the ~2EZ approach to deal with missing CVRs. This can greatly increase the efficiency of the audit if
# some contests appear on only a small percentage of the cast cards ([Glazer, Spertus, and Stark, 2021](https://dl.acm.org/doi/10.1145/3457907)).
# If there are more CVRs than the upper bound on the number of cards, extra CVRs can be deleted provided
# that deletion does not change any contest outcome. See [Stark, 2022](https://arxiv.org/abs/2207.01362).
# (However, if there more CVRs than cards, that is evidence of a process failure.)
#
# Any sampled phantom card (i.e., a card for which there is no CVR) is treated as if its CVR is a non-vote (which it is), and as if its MVR was least favorable (an "evil zombie" producing the greatest doubt in every assertion, separately). Any sampled card for which there is a CVR is compared to its corresponding CVR.
# If the card turns out not to contain the contest (despite the fact that the CVR says it does), the MVR is treated in the least favorable way for each assertion (i.e., as a zombie rather than as a non-vote).
#
# The tool helps select cards for audit, and reports when the audit has found sufficiently strong evidence to stop.
#
# The tool exports a log of all the audit inputs except the CVR file, but including the auditors' manually determined voter intent from the audited cards.
#
# The pre-10/2021 version used a single sample to audit all contests.

# %% [markdown]
# ### Internal workflow
#
# + Read overall audit information (including the seed) and contest information
# + Read assertions for IRV contests and construct assertions for all other contests
# + Read ballot manifest
# + Read cvrs. Every CVR should have a corresponding manifest entry.
# + Prepare ~2EZ:
#     - `N_phantoms = max_cards - cards_in_manifest`
#     - If `N_phantoms < 0`, complain
#     - Else create `N_phantoms` phantom cards
#     - For each contest `c`:
#         + `N_c` is the input upper bound on the number of cards that contain `c`
#         + if `N_c is None`, `N_c = max_cards - non_c_cvrs`, where `non_c_cvrs` is #CVRs that don't contain `c`
#         + `C_c` is the number of CVRs that contain the contest
#         + if `C_c > N_c`, complain
#         + else if `N_c - C_c > N_phantoms`, complain
#         + else:
#             - Consider contest `c` to be on the first `N_c - C_c` phantom CVRs
#             - Consider contest `c` to be on the first `N_c - C_c` phantom ballots
# + Create Assertions for every Contest. This involves also creating an Assorter for every Assertion, and a `NonnegMean` test
# for every Assertion.
# + Calculate assorter margins for all assorters:
#     - If `not use_style`, apply the Assorter to all cards and CVRs, including phantoms
#     - Else apply the assorter only to cards/cvrs reported to contain the contest, including phantoms that contain the contest
# + Set `assertion.test.u` to the appropriate value for each assertion: `assorter.upper_bound` for polling audits or
#       `2/(2-assorter.margin/assorter.upper_bound)` for ballot-level comparison audits
# + Estimate starting sample size for the specified sampling design (w/ or w/o replacement, stratified, etc.), for chosen risk function, use of card-style information, etc.:
#     - User-specified criterion, controlled by parameters. Examples:
#         + expected sample size for completion, on the assumption that there are no errors
#         + 90th percentile of sample size for completion, on the assumption that errors are not more frequent than specified
#     - If `not use_style`, base estimate on sampling from the entire manifest, i.e., smallest assorter margin
#     - Else use consistent sampling:
#         + Augment each CVR (including phantoms) with a probability of selection, `p`, initially 0
#         + For each contest `c`:
#             - Find sample size `n_c` that meets the criterion
#             - For each non-phantom CVR that contains the contest, set `p = max(p, n_c/N_c)`
#         + Estimated sample size is the sum of `p` over all non-phantom CVRs
# + Draw the random sample:
#     - Use the specified design, including using consistent sampling for style information
#     - Express sample cards in terms of the manifest
#     - Export
# + Read manual interpretations of the cards (MVRs)
# + Calculate attained risk for each assorter
#     - Use ~2EZ to deal with phantom CVRs or cards; the treatment depends on whether `use_style == True`
# + Report
# + Estimate incremental sample size if any assorter nulls have not been rejected
# + Draw incremental sample; etc

# %% [markdown]
# # Audit parameters.
#
# The overall audit involves information that is the same across contests, encapsulated in
# a dict called `audit`:
#
# * `seed`: the numeric seed for the pseudo-random number generator used to draw sample (for SHA256 PRNG)
# * `sim_seed`: seed for simulations to estimate sample sizes (for Mersenne Twister PRNG)
# * `quantile`: quantile of the sample size to use for setting initial sample size
# * `cvr_file`: filename for CVRs (input)
# * `manifest_file`: filename for ballot manifest (input)
# * `use_style`: Boolean. If True, use card style information (inferred from CVRs) to target samples. If False, sample from all cards, regardless of the contest.
# * `sample_file`: filename for sampled card identifiers (output)
# * `mvr_file`: filename for manually ascertained votes from sampled cards (input)
# * `log_file`: filename for audit log (output)
# * `error_rate_1`: expected rate of 1-vote overstatements. Recommended value $\ge$ 0.001 if there are hand-marked ballots. Larger values increase the initial sample size, but make it more likely that the audit will conclude after a single round even if the audit finds errors
# * `error_rate_2`: expected rate of 2-vote overstatements. 2-vote overstatements should be extremely rare.
# Recommended value: 0. Larger values increase the initial sample size, but make it more likely that the audit will conclude after a single round even if the audit finds errors
# * `reps`: number of replications to use to estimate sample sizes. If `reps is None`, uses a deterministic method
# * `quantile`: quantile of sample size to estimate. Not used if `reps is None`
# * `strata`: a dict describing the strata. Keys are stratum identifiers; values are dicts containing:
#     + `max_cards`: an upper bound on the number of pieces of paper cast in the contest. This should be derived independently of the voting system. A ballot consists of one or more cards.
#     + `replacement`: whether to sample from this stratum with replacement.
#     + `use_style`: True if the sample in that stratum uses card-style information.
#     + `audit_type` one of Contest.POLLING, Contest.BALLOT_COMPARISON, Contest.BATCH_COMPARISON but only POLLING and BALLOT_COMPARISON are currently implemented.
#     + `test`: the name of the function to be used to measure risk. Options are `kaplan_markov`,`kaplan_wald`,`kaplan_kolmogorov`,`wald_sprt`,`kaplan_mart`, `alpha_mart`.
# Not all risk functions work with every social choice function or every sampling method.
#     + `estimator`: the estimator to be used by the risk function. Options are [FIX ME!]
#     + `test_kwargs`: keyword arguments for the risk function
#
# ----
#
# * `contests`: a dict of contest-specific data
#     + the keys are unique contest identifiers for contests under audit
#     + the values are Contest objects with attributes:
#         - `risk_limit`: the risk limit for the audit of this contest
#         - `cards`: an upper bound on the number of cast cards that contain the contest
#         - `choice_function`: `Audit.SOCIAL_CHOICE_FUNCTION.PLURALITY`,
#           `Audit.SOCIAL_CHOICE_FUNCTION.SUPERMAJORITY`, or `Audit.SOCIAL_CHOICE_FUNCTION.IRV`
#         - `n_winners`: number of winners for majority contests. (Multi-winner IRV not supported)
#         - `share_to_win`: for super-majority contests, the fraction of valid votes required to win, e.g., 2/3. share_to_win*n_winners must be less than 100%)
#         - `candidates`: list of names or identifiers of candidates
#         - `reported_winners` : list of identifier(s) of candidate(s) reported to have won. Length should equal `n_winners`.
#         - `assertion_file`: filename for a set of json descriptors of Assertions (see technical documentation) that collectively imply the reported outcome of the contest is correct. Required for IRV; ignored for other social choice functions
#         - `audit_type`: the audit strategy. Currently `Audit.AUDIT_TYPE.POLLING (ballot-polling)` and
#            `Audit.AUDIT_TYPE.BALLOT_COMPARISON` (ballot-level comparison audits) are implemented.
#            HYBRID and STRATIFIED are planned.
#         - `test`: the risk function for the audit. Default is `NonnegMean.alpha_mart`, the alpha supermartingale test
#         - `estim`: estimator for the alternative hypothesis for the test. Default is `NonnegMean.shrink_trunc`
#         - `use_style`: True to use style information from CVRs to target the sample. False for polling audits or for sampling from all ballots for every contest.
#         - other keys and values are added by the software, including `cvrs`, the number of CVRs that contain the contest, and `p`, the sampling fraction expected to be required to confirm the contest

# %%
import math
import json
import warnings
import numpy as np
import pandas as pd
import csv
import copy
import matplotlib.pyplot as plt

from collections import OrderedDict
from IPython.display import display, HTML

from cryptorandom.cryptorandom import SHA256, int_from_hash
from cryptorandom.sample import sample_by_index

from Audit import Audit, Assertion, Assorter, Contest, CVR, Stratum
from NonnegMean import NonnegMean
from Dominion import Dominion
from Hart import Hart

# %%
audit = Audit.from_dict({
         'seed':           12345678901234567890,
         'sim_seed':       314159265,
         'cvr_file':       '/Users/amanda/Downloads/oc_cvrs.zip', 
         #'cvr_file':       '/Users/Jake/Desktop/oc_cvrs.zip', 
         #'manifest_file':  'Data/OC_mock_manifest_detailed.xlsx',
         'manifest_file': 'Data/OC_full_manifest.xlsx',
         #'manifest_file': 'tests/Data/Hart_manifest.xlsx',
         'sample_file':    '',
         'mvr_file':       '',
         'log_file':       'Data/OC_example_log.json',
         'quantile':       0.8,
         'error_rate_1': 0,
         'error_rate_2': 0,
         #'error_rate_1':   0.001,
         #'error_rate_2':   0.0001,
         'reps':           100,
         'strata':         {'stratum_1': {'max_cards':   3094308, 
                                          'use_style':   True,
                                          'replacement': False,
                                          'audit_type':  Audit.AUDIT_TYPE.BALLOT_COMPARISON,
                                          'test':        NonnegMean.alpha_mart,
                                          'estimator':   NonnegMean.optimal_comparison,
                                          'test_kwargs': {}
                                         }
                           }
        })

# find upper bound on total cards across strata
audit.max_cards = np.sum([s.max_cards for s in audit.strata.values()])

# %%
# plur_cvr_list = CVR.from_dict([
#                {'id': "1_1", 'votes': {'AvB': {'Alice':True}}},
#                {'id': "1_2", 'votes': {'AvB': {'Bob':True}}},
#                {'id': "1_3", 'votes': {'AvB': {'Alice':True}}},
#                {'id': "1_4", 'votes': {'AvB': {'Alice':True}}}])
# plur_con_test = Contest.from_dict({'id': 'AvB',
#              'name': 'AvB',
#              'risk_limit': 0.05,
#              'cards': 4,
#              'choice_function': Contest.SOCIAL_CHOICE_FUNCTION.PLURALITY,
#              'n_winners': 1,
#              'candidates': 3,
#              'candidates': ['Alice','Bob','Candy'],
#              'winner': ['Alice'],
#              'audit_type': Audit.AUDIT_TYPE.BALLOT_COMPARISON,
#              'test': NonnegMean.alpha_mart,
#              'estim': NonnegMean.optimal_comparison,
#              'use_style': True
#             })
# #assertion without a margin
# raw_AvB_asrtn = Assertion(
#     contest = plur_con_test,
#     winner = "Alice",
#     loser = "Bob",
#     test = NonnegMean(test=plur_con_test.test, estim=plur_con_test.estim, u=1,
#                         N=plur_con_test.cards, t=1/2, random_order=True),
#     assorter = Assorter(
#         contest = plur_con_test,
#         assort = lambda c:
#                      (CVR.as_vote(c.get_vote_for("AvB", "Alice"))
#                      - CVR.as_vote(c.get_vote_for("AvB", "Bob"))
#                       + 1)/2,
#         upper_bound = 1
#     )
# )

# %%
#raw_AvB_asrtn.test.u
# Out:
# 1

# %%
# %%time
#cvr_zip = "/Users/Jake/Desktop/oc_cvrs.zip"
cvr_zip = "/Users/amanda/Downloads/oc_cvrs.zip"
#cvr_list = Hart.read_cvrs_directory("/Users/Jake/Dropbox/RLAs/Orange County Audit/cvrs_for_testing_v2")
#cvr_list = Hart.read_cvrs_zip(cvr_zip, size = 10000) # sample of 10000 CVRs
cvr_list = Hart.read_cvrs_zip(cvr_zip, size = 3094308) # all (XML) CVRs that can be read without error
#cvr_list = Hart.read_cvrs_zip(cvr_zip) # all CVRs
# Out:
# CPU times: user 10min 53s, sys: 9.51 s, total: 11min 2s
# Wall time: 11min 3s

# %%
votes = CVR.tabulate_votes(cvr_list)
styles = CVR.tabulate_styles(cvr_list)
cards = CVR.tabulate_cards_contests(cvr_list) # TO DO: change this to just utilize output of tabulate_votes

# %%
#{key: value for key, value in sorted(cards.items())}
cards
# Out:
# defaultdict(int,
#             {'Proposition 19': 1546057,
#              'Proposition 20': 1545902,
#              'Proposition 21': 1545587,
#              'Proposition 22': 1545469,
#              'Proposition 23': 1545467,
#              'Proposition 24': 1545357,
#              'Proposition 25': 1545355,
#              'AA-City of Orange': 67580,
#              'Proposition 14': 1546323,
#              'Proposition 15': 1546320,
#              'Proposition 16': 1546310,
#              'Proposition 17': 1546210,
#              'Proposition 18': 1546204,
#              'Z-City of Newport Beach': 55753,
#              'CC-City of Tustin': 35264,
#              'S-City of Fullerton': 65007,
#              'U-City of Fullerton': 65007,
#              'DD-City of Westminster': 42391,
#              'Y-City of Los Alamitos': 6264,
#              'Q-City of Costa Mesa': 54083,
#              'P-City of Cypress': 26372,
#              'BB-City of San Clemente': 40134,
#              'W-City of La Habra': 27756,
#              'X-City of La Habra': 27756,
#              'V-City of Laguna Woods': 13850,
#              'ORANGE COUNTY WATER DISTRICT\nDirector, Division 4': 119703,
#              'MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 3': 157203,
#              'ORANGE COUNTY WATER DISTRICT\nDirector, Division 6': 136190,
#              'CITY OF GARDEN GROVE\nMayor': 70723,
#              'IRVINE RANCH WATER DISTRICT\nDirector, Division 4': 38824,
#              'CITY OF WESTMINSTER\nMember, City Council, District 3': 10926,
#              'MIDWAY CITY SANITARY DISTRICT\nDirector': 45762,
#              'IRVINE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3': 17147,
#              'CITY OF IRVINE\nMayor': 129948,
#              'CITY OF IRVINE\nMember, City Council': 129948,
#              'MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 4': 189439,
#              'CITY OF TUSTIN\nMember, City Council': 35282,
#              'EAST ORANGE COUNTY WATER DISTRICT\nDirector': 45552,
#              'CITY OF SANTA ANA\nMember, City Council, Ward 3': 22031,
#              'MESA WATER DISTRICT\nDirector, Division 2': 10425,
#              'CITY OF HUNTINGTON BEACH\nCity Clerk': 119371,
#              'CITY OF HUNTINGTON BEACH\nCity Treasurer': 119371,
#              'MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 1, Short Term': 168963,
#              'CITY OF WESTMINSTER\nMember, City Council, District 2': 8413,
#              'BUENA PARK LIBRARY DISTRICT\nTrustee': 35190,
#              'CITY OF GARDEN GROVE\nMember, City Council, District 6': 8434,
#              'MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 7': 191471,
#              'SANTA MARGARITA WATER DISTRICT\nDirector': 99226,
#              'CITY OF HUNTINGTON BEACH\nMember, City Council': 119371,
#              'CITY OF SANTA ANA\nMayor': 95571,
#              'CITY OF SAN CLEMENTE\nMember, City Council, Full Term': 40150,
#              'CITY OF SAN CLEMENTE\nMember, City Council, Short Term': 40150,
#              'CITY OF SAN CLEMENTE\nCity Clerk': 40150,
#              'CITY OF SAN CLEMENTE\nCity Treasurer': 40150,
#              'CITY OF ORANGE\nCity Treasurer': 67614,
#              'PRESIDENT AND VICE PRESIDENT': 1546327,
#              'UNITED STATES REPRESENTATIVE\n45th District': 426088,
#              'STATE SENATOR\n37th District': 549633,
#              'MEMBER OF THE STATE ASSEMBLY\n68th District': 269096,
#              'ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 
CHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3': 15034,
#              'CITY OF DANA POINT\nMember, City Council, District 5': 4290,
#              'BUENA PARK SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 4': 2843,
#              'CITY OF PLACENTIA\nMember, City Council, District 1': 2669,
#              'CITY OF PLACENTIA\nMember, City Council, District 5': 6632,
#              'CITY OF LOS ALAMITOS\nMember, City Council, District 2': 1220,
#              'CITY OF LAKE FOREST\nMember, City Council, District 5': 6274,
#              'CITY OF SAN JUAN CAPISTRANO\nMember, City Council, District 5': 5668,
#              'CITY OF LOS ALAMITOS\nMember, City Council, District 3': 1276,
#              'HUNTINGTON BEACH CITY SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 1': 11448,
#              'SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT\nDirector, Full Term': 568,
#              'SILVERADO-MODJESKA RECREATION AND PARK DISTRICT\nDirector': 1165,
#              'CITY OF STANTON\nMember, City Council, District 2': 2990,
#              'CAPISTRANO BAY COMMUNITY SERVICES DISTRICT\nDirector': 109})

# %%
#official 2020 results at https://ocvote.gov/data/election-results-archives 
votes['PRESIDENT AND VICE PRESIDENT'] #official: 814,009 for Biden and 676,498 for Trump 
#votes['UNITED STATES REPRESENTATIVE\n39th District'] #official: 115,034 for Young Kim and 105,133 for Gil Cisneros
#votes['SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT\nDirector, Full Term'] #official: 248 for James Guziak and 205 for Craig Schill
# Out:
# defaultdict(int,
#             {'__cards__': 1546327,
#              'DONALD J. TRUMP\nMICHAEL R. PENCE': 676752,
#              'JOSEPH R. BIDEN\nKAMALA D. HARRIS': 814392,
#              'WRITE_IN': 9440,
#              'ROQUE "ROCKY" DE LA FUENTE GUERRA\nKANYE OMARI WEST': 4829,
#              'JO JORGENSEN\nJEREMY "SPIKE" COHEN': 17492,
#              'HOWIE HAWKINS\nANGELA NICOLE WALKER': 5964,
#              'GLORIA LA RIVA\nSUNIL FREEMAN': 3808})

# %%
## Code to create manifest based on CVRs given
# Create manifest_dict to store batch name and number of ballots
# manifest_dict = {}
# for i in range(len(cvr_list)):
#     cvr_id = cvr_list[i].id
#     # CVR id has format (batch number)_(sheet)
#     batch, card_num = cvr_id.split("_")
#     # check if batch already in dict
#     if batch in manifest_dict.keys():
#         # if so add one to existing ballot count
#         manifest_dict[batch] = manifest_dict[batch] + 1
#     else:
#         # otherwise create key with value one
#         manifest_dict[batch] = 1
# # Convert dict info into dataframe
# manifest = pd.DataFrame({'Batch Name' : manifest_dict.keys(),
#              'Number of Ballots' : manifest_dict.values(),
#              'Container' : 1, 
#              'Tabulator' : 99808})
# manifest['cum_cards'] = np.array(np.cumsum(manifest['Number of Ballots']))
# write csv
# manifest.to_excel('Data/OC_full_manifest.xlsx', index=False)

# %%
# #Contests to audit

# contest_dict = {'Proposition 19':{
#                    'name': 'Prop 19',
#                    'risk_limit': 0.05,
#                    'cards': 682236 + 84547 + 779688 + 10, # should create 10 phantoms
#                    'choice_function': Contest.SOCIAL_CHOICE_FUNCTION.PLURALITY, # in @Contest, not @Audit
#                    'n_winners': 1,
#                    'candidates': ['Yes','No'],
#                    'winner': ['No'],
#                    'assertion_file': None,
#                    'audit_type': Audit.AUDIT_TYPE.BALLOT_COMPARISON,
#                    'test': NonnegMean.alpha_mart,
#                    'estim': NonnegMean.optimal_comparison
#                   },
#                 'Proposition 20':{
#                    'name': 'Prop 20',
#                    'risk_limit': 0.05,
#                    'cards': 845736 + 615021 + 85706 + 10, # should create 10 phantoms
#                    'choice_function': Contest.SOCIAL_CHOICE_FUNCTION.PLURALITY, # in @Contest, not @Audit
#                    'n_winners': 1,
#                    'candidates': ['Yes','No'],
#                    'winner': ['No'],
#                    'assertion_file': None,
#                    'audit_type': Audit.AUDIT_TYPE.BALLOT_COMPARISON,
#                    'test': NonnegMean.alpha_mart,
#                    'estim': NonnegMean.optimal_comparison
#                   },
#                 'Proposition 21':{
#                    'name': 'Prop 21',
#                    'risk_limit': 0.05,
#                    'cards': 501722 + 973927 + 70257 + 10, # should create 10 phantoms
#                    'choice_function': Contest.SOCIAL_CHOICE_FUNCTION.PLURALITY, # in @Contest, not @Audit
#                    'n_winners': 1,
#                    'candidates': ['Yes','No'],
#                    'winner': ['No'],
#                    'assertion_file': None,
#                    'audit_type': Audit.AUDIT_TYPE.BALLOT_COMPARISON,
#                    'test': NonnegMean.alpha_mart,
#                    'estim': NonnegMean.optimal_comparison
#                   },
#                 'V-City of Laguna Woods':{
#                    'name': 'Measure V',
#                    'risk_limit': 0.05,
#                    'cards': 6428 + 6653 + 771 + 10, # should create 10 phantoms
#                    'choice_function': Contest.SOCIAL_CHOICE_FUNCTION.PLURALITY, # in @Contest, not @Audit
#                    'n_winners': 1,
#                    'candidates': ['Yes','No'],
#                    'winner': ['Yes'],
#                    'assertion_file': None,
#                    'audit_type': Audit.AUDIT_TYPE.BALLOT_COMPARISON,
#                    'test': NonnegMean.alpha_mart,
#                    'estim': NonnegMean.optimal_comparison
#                   }
#                }

# contests = Contest.from_dict_of_dicts(contest_dict)

# %%
#make dict of all contests in CVRs
# NOTE: use_style False flag
contests = Contest.from_cvr_list(votes, cards, cvr_list, use_style = True)

# %%
print(contests['PRESIDENT AND VICE PRESIDENT'])
# Out:
# {'id': 'PRESIDENT AND VICE PRESIDENT', 'name': 'PRESIDENT AND VICE PRESIDENT', 'risk_limit': 0.05, 'cards': 1546327, 'choice_function': 'PLURALITY', 'n_winners': 1, 'share_to_win': None, 'candidates': ['DONALD J. TRUMP\nMICHAEL R. PENCE', 'JOSEPH R. BIDEN\nKAMALA D. HARRIS', 'WRITE_IN', 'ROQUE "ROCKY" DE LA FUENTE GUERRA\nKANYE OMARI WEST', 'JO JORGENSEN\nJEREMY "SPIKE" COHEN', 'HOWIE HAWKINS\nANGELA NICOLE WALKER', 'GLORIA LA RIVA\nSUNIL FREEMAN'], 'winner': ['JOSEPH R. BIDEN\nKAMALA D. HARRIS'], 'assertion_file': None, 'audit_type': 'BALLOT_COMPARISON', 'test': <function NonnegMean.alpha_mart at 0x7fb1c19cf040>, 'g': 0.1, 'estim': <function NonnegMean.optimal_comparison at 0x7fb1c19cf430>, 'use_style': True, 'assertions': None, 'tally': None, 'sample_size': None}

# %%
# Create array of vote for 2 contests
vote_for_two = ['LAGUNA BEACH UNIFIED SCHOOL DISTRICT\nGoverning Board Member', 
               'HUNTINGTON BEACH UNION HIGH SCHOOL DISTRICT\nGoverning Board Member', 
               'FOUNTAIN VALLEY SCHOOL DISTRICT\nGoverning Board Member', 
               'LA HABRA CITY SCHOOL DISTRICT\nGoverning Board Member,\nFull Term',
               'CITY OF BREA\nMember, City Council', 
               'CITY OF CYPRESS\nMember, City Council', 
               'CITY OF FOUNTAIN VALLEY\nMember, City Council',
                'CITY OF LAGUNA BEACH\nMember, City Council',
                'CITY OF LAGUNA HILLS\nMember, City Council',
                'CITY OF MISSION VIEJO\nMember, City Council,\nTwo-Year Term',
                'RANCHO SANTA MARGARITA\nMember, City Council',
                'CITY OF SAN CLEMENTE\nMember, City Council, Full Term', 
                'CAPISTRANO BAY COMMUNITY SERVICES DISTRICT\nDirector',
                'SILVERADO-MODJESKA RECREATION AND PARK DISTRICT\nDirector',
                'MIDWAY CITY SANITARY DISTRICT\nDirector',
                'SURFSIDE COLONY STORM WATER PROTECTION DISTRICT\nTrustee',
                'EAST ORANGE COUNTY WATER DISTRICT\nDirector',
                'SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT\nDirector, Full Term'
               ]
# Create array of vote for 3 contests
vote_for_three = ['SANTA ANA UNIFIED SCHOOL DISTRICT\nGoverning Board Member',
                  'CITY OF ALISO VIEJO\nMember, City Council',
                  'CITY OF HUNTINGTON BEACH\nMember, City Council',
                  'CITY OF IRVINE\nMember, City Council',
                  'CITY OF LAGUNA NIGUEL\nMember, City Council',
                  'CITY OF LAGUNA WOODS\nMember, City Council',
                  'CITY OF LA HABRA\nMember, City Council', 
                  'CITY OF LA PALMA\nMember, City Council',
                  'CITY OF TUSTIN\nMember, City Council',
                  'ROSSMOOR COMMUNITY SERVICES DISTRICT\nDirector, Full Term',
                  'SUNSET BEACH SANITARY DISTRICT\nDirector, Full Term',
                  'SANTA MARGARITA WATER DISTRICT\nDirector', 
                  'SOUTH COAST WATER DISTRICT\nDirector',
                  'BUENA PARK LIBRARY DISTRICT\nTrustee'
                 ]
# Update dictionary with correct n_winners
for con in vote_for_two:
    contests[con].n_winners = 2
    
for con in vote_for_three:
    contests[con].n_winners = 3

# %%
## Fix winners lists
contests['LAGUNA BEACH UNIFIED SCHOOL DISTRICT\nGoverning Board Member'].winner = ['KELLY OSBORNE', 'JAN VICKERS']
contests['HUNTINGTON BEACH UNION HIGH SCHOOL DISTRICT\nGoverning Board Member'].winner = ['SUSAN HENRY', 'MICHAEL SIMONS']
contests['FOUNTAIN VALLEY SCHOOL DISTRICT\nGoverning Board Member'].winner = ['STEVE SCHULTZ', 'JEANNE GALINDO']
contests['LA HABRA CITY SCHOOL DISTRICT\nGoverning Board Member,\nFull Term'].winner = ['SUSAN M. PRITCHARD', 'OFELIA CORONA HANSON']
contests['CITY OF BREA\nMember, City Council'].winner = ['CHRISTINE MARICK', 'MARTY SIMONOFF']
contests['CITY OF CYPRESS\nMember, City Council'].winner = ['ANNE HERTZ', 'FRANCES MARQUEZ']
contests['CITY OF FOUNTAIN VALLEY\nMember, City Council'].winner = ['GLENN GRANDIS', 'TED BUI']
contests['CITY OF LAGUNA BEACH\nMember, City Council'].winner = ['BOB WHALEN', 'GEORGE WEISS']
contests['CITY OF LAGUNA HILLS\nMember, City Council'].winner = ['JANINE HEFT', 'BILL HUNT']
contests['CITY OF MISSION VIEJO\nMember, City Council,\nTwo-Year Term'].winner = ['PATRICIA "TRISH" KELLEY', 'BRIAN GOODELL']
contests['RANCHO SANTA MARGARITA\nMember, City Council'].winner = ['TONY BEALL', 'CAROL GAMBLE']
contests['CITY OF SAN CLEMENTE\nMember, City Council, Full Term'].winner = ['GENE JAMES', 'CHRIS DUNCAN'] 
contests['CAPISTRANO BAY COMMUNITY SERVICES DISTRICT\nDirector'].winner = ['BRAD L. JENKINS', 'WILLIAM WIERSIG']
contests['SILVERADO-MODJESKA RECREATION AND PARK DISTRICT\nDirector'].winner = ['MICHELE GRACE AGOPIAN', 'JULIE A. MORRIS']
contests['MIDWAY CITY SANITARY DISTRICT\nDirector'].winner = ['CHI CHARLIE NGUYEN', 'TYLER DIEP']
# double check surfside winners..
contests['SURFSIDE COLONY STORM WATER PROTECTION DISTRICT\nTrustee'].winner = ['DAVE CHAMBERLAIN', 'VICTOR J. KRISS']
contests['EAST ORANGE COUNTY WATER DISTRICT\nDirector'].winner = ['DOUGLASS S. DAVERT', 'JOHN L SEARS']
contests['SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT\nDirector, Full Term'].winner = ['JAMES GUZIAK', 'CRAIG S. SCHILL']

contests['SANTA ANA UNIFIED SCHOOL DISTRICT\nGoverning Board Member'].winner = ['CAROLYN TORRES', 'RIGO RODRIGUEZ', 'ALFONSO ALVAREZ']
contests['CITY OF ALISO VIEJO\nMember, City Council'].winner = ['MIKE MUNZING', 'ROSS CHUN', 'RICHARD HURT']
contests['CITY OF HUNTINGTON BEACH\nMember, City Council'].winner = ['TITO ORTIZ', 'DAN KALMICK', 'NATALIE MOSER']
contests['CITY OF IRVINE\nMember, City Council'].winner = ['TAMMY KIM', 'MIKE CARROLL', 'LARRY AGRAN']
contests['CITY OF LAGUNA NIGUEL\nMember, City Council'].winner = ['SANDY RAINS', 'RISCHI PAUL SHARMA', 'KELLY JENNINGS']
contests['CITY OF LAGUNA WOODS\nMember, City Council'].winner = ['NOEL HATCH', 'SHARI L HORNE', 'CYNTHIA CONNERS']
contests['CITY OF LA HABRA\nMember, City Council'].winner = ['ROSE ESPINOZA', 'TIM SHAW', 'STEVE SIMONIAN']
contests['CITY OF LA PALMA\nMember, City Council'].winner = ['MARSHALL GOODMAN', 'DEBBIE BAKER', 'MARK I. WALDMAN']
contests['CITY OF TUSTIN\nMember, City Council'].winner = ['LETITIA CLARK', 'REBECCA "BECKIE" GOMEZ', 'RYAN GALLAGHER']
contests['ROSSMOOR COMMUNITY SERVICES DISTRICT\nDirector, Full Term'].winner = ['JEFFREY BARKE', 'TONY DEMARCO', 'NATHAN SEARLES']
contests['SUNSET BEACH SANITARY DISTRICT\nDirector, Full Term'].winner = ['DAVID EVANS', 'JOHN H. WOODS', 'JON H. REGNIER']
contests['SANTA MARGARITA WATER DISTRICT\nDirector'].winner = ['CHARLES "CHUCK" GIBSON', 'BETTY H. OLSON', 'FRANK URY']
contests['SOUTH COAST WATER DISTRICT\nDirector'].winner = ['RICK ERKENEFF', 'SCOTT GOLDMAN', 'DOUGLAS ERDMAN']
contests['BUENA PARK LIBRARY DISTRICT\nTrustee'].winner = ['PATRICIA GANER', 'IRENE CASTANEDA', 'L CAROLE JENSEN']

# %%
# construct the dict of dicts of assertions for each contest
Assertion.make_all_assertions(contests)
# Out:
# True

# %%
audit.check_audit_parameters(contests)

# %% [markdown]
# ## Read the ballot manifest

# %%
# special for Primary/Dominion manifest format
manifest = pd.read_excel(audit.manifest_file)

# %%
manifest.head()
# Out:
#    Batch Name  Number of Ballots  Container  Tabulator  cum_cards
# 0         274               2829          1      99808       2829
# 1           0             523869          1      99808     526698
# 2         140               9333          1      99808     536031
# 3         106              10762          1      99808     546793
# 4         124              10067          1      99808     556860

# %%
# check whether the manifest accounts for every card
# it doesn't because phantoms 
audit.max_cards, np.sum(manifest['Number of Ballots'].astype(int))
# Out:
# (3094308, 3094308)

# %%
# Check that there is a card in the manifest for every card (possibly) cast. If not, add phantoms.
manifest, manifest_cards, phantom_cards = Hart.prep_manifest(manifest, audit.max_cards, len(cvr_list))
#manifest

# %%
## NOTE: for some reason prep manifest turns all the columns into string type..
audit.max_cards, np.sum(manifest['Number of Ballots'].astype(int))
# Out:
# (3094308, 3094308)

# %% [markdown]
# ## Create CVRs for phantom cards

# %%
# For Comparison Audits Only
#----------------------------

# If the sample draws a phantom card, these CVRs will be used in the comparison.
# phantom MVRs should be treated as zeros by the Assorter for every contest

# setting use_style = False to generate phantoms

cvr_list, phantom_vrs = CVR.make_phantoms(audit=audit, contests=contests, 
                                          cvr_list=cvr_list, prefix='phantom-1-')
print(f"Created {phantom_vrs} phantom records")
# Out:
# Created 0 phantom records

# %%
# %%time
# find the mean of the assorters for the CVRs and check whether the assertions are met
# this takes a very long time to run on all contests
min_margin = Assertion.set_all_margins_from_cvrs(audit=audit, contests=contests, 
                                                 cvr_list=cvr_list)

print(f'minimum assorter margin {min_margin}')
Contest.print_margins(contests)
# Out:
# minimum assorter margin 0.00024015369836694056
# margins in contest Proposition 19:
# 	assertion No v Yes: 0.0630326048780867
# margins in contest Proposition 20:
# 	assertion No v Yes: 0.149242966242362
# margins in contest Proposition 21:
# 	assertion No v Yes: 0.30551822705548126
# margins in contest Proposition 22:
# 	assertion Yes v No: 0.3062759589483839
# margins in contest Proposition 23:
# 	assertion No v Yes: 0.3220832279175161
# margins in contest Proposition 24:
# 	assertion Yes v No: 0.07609827373221845
# margins in contest Proposition 25:
# 	assertion No v Yes: 0.20379653865940184
# margins in contest AA-City of Orange:
# 	assertion No v Yes: 0.2450281148268718
# margins in contest Proposition 14:
# 	assertion No v Yes: 0.07636179504540763
# margins in contest Proposition 15:
# 	assertion No v Yes: 0.20308927000879518
# margins in contest Proposition 16:
# 	assertion No v Yes: 0.29275436361402307
# margins in contest Proposition 17:
# 	assertion No v Yes: 0.0042212894755564445
# margins in contest Proposition 18:
# 	assertion No v Yes: 0.27502580513308716
# margins in contest Z-City of Newport Beach:
# 	assertion Yes v No: 0.08776209351963127
# margins in contest CC-City of Tustin:
# 	assertion Yes v No: 0.44592218693284935
# margins in contest S-City of Fullerton:
# 	assertion No v Yes: 0.13836971403079668
# margins in contest U-City of Fullerton:
# 	assertion No v Yes: 0.19024105096374244
# margins in contest DD-City of Westminster:
# 	assertion Yes v No: 0.4846547616239296
# margins in contest Y-City of Los Alamitos:
# 	assertion Yes v No: 0.017879948914431676
# margins in contest Q-City of Costa Mesa:
# 	assertion Yes v No: 0.28654105726383516
# margins in contest P-City of Cypress:
# 	assertion Yes v No: 0.33728954952222057
# margins in contest BB-City of San Clemente:
# 	assertion Yes v No: 0.49793192804106234
# margins in contest W-City of La Habra:
# 	assertion Yes v No: 0.33059518662631504
# margins in contest X-City of La Habra:
# 	assertion Yes v No: 0.4724744199452371
# margins in contest V-City of Laguna Woods:
# 	assertion Yes v No: 0.016245487364620947
# margins in contest ORANGE COUNTY WATER DISTRICT
# Director, Division 4:
# 	assertion TRI TA v JASMIN CARMADELLA: 0.26814699715128265
# 	assertion TRI TA v SAMANTHA BAO ANH NGUYEN: 0.3414283685454833
# 	assertion TRI TA v KRIS BEARD: 0.186352890069589
# 	assertion TRI TA v TAI DO: 0.29818801533796147
# 	assertion TRI TA v WRITE_IN: 0.38251338730023465
# margins in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 3:
# 	assertion ROBERT R. "BOB" MCVICKER v LINDA MOULTON-PATTERSON: 0.28073255599447844
# 	assertion ROBERT R. "BOB" MCVICKER v TYLER DIEP: 0.14707734585217835
# 	assertion ROBERT R. "BOB" MCVICKER v KATHY-NGUYET PHAM: 0.2766868316762403
# 	assertion ROBERT R. "BOB" MCVICKER v WRITE_IN: 0.38630306037416595
# margins in contest ORANGE COUNTY WATER DISTRICT
# Director, Division 6:
# 	assertion CATHY GREEN v MICHAEL ELLIOTT: 0.16729568984506948
# 	assertion CATHY GREEN v WRITE_IN: 0.4839709229752551
# margins in contest CITY OF GARDEN GROVE
# Mayor:
# 	assertion STEVE JONES v PHAT BUI: 0.30656222162521396
# 	assertion STEVE JONES v WRITE_IN: 0.5663645490151719
# 	assertion STEVE JONES v DONALD TAYLOR: 0.5254726185257979
# 	assertion STEVE JONES v DUY NGUYEN: 0.5248221936286639
# margins in contest IRVINE RANCH WATER DISTRICT
# Director, Division 4:
# 	assertion KAREN MCLAUGHLIN v MARY AILEEN MATHEIS: 0.11701524830002064
# 	assertion KAREN MCLAUGHLIN v AARTI KAUSHAL: 0.3732485060787143
# 	assertion KAREN MCLAUGHLIN v WRITE_IN: 0.42445394601277564
# margins in contest CITY OF WESTMINSTER
# Member, City Council, District 3:
# 	assertion KIMBERLY HO v WRITE_IN: 0.5654402343034963
# 	assertion KIMBERLY HO v TAI DO: 0.2619439868204283
# margins in contest MIDWAY CITY SANITARY DISTRICT
# Director:
# 	assertion CHI CHARLIE NGUYEN v JAMISON POWER: 0.11489882435208254
# 	assertion CHI CHARLIE NGUYEN v WRITE_IN: 0.420676543857349
# 	assertion CHI CHARLIE NGUYEN v TAI DO: 0.2498361085616887
# 	assertion CHI CHARLIE NGUYEN v ASHTON ROGER KAUWE: 0.33814081552379704
# 	assertion TYLER DIEP v JAMISON POWER: 0.03033084218347093
# 	assertion TYLER DIEP v WRITE_IN: 0.3361085616887374
# 	assertion TYLER DIEP v TAI DO: 0.1652681263930773
# 	assertion TYLER DIEP v ASHTON ROGER KAUWE: 0.25357283335518543
# margins in contest IRVINE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assert
# 	assertion JOHN L SEARS v WRITE_IN: 0.3378995433789955
# margins in contest CITY OF SANTA ANA
# Member, City Council, Ward 3:
# 	assertion JESSIE LOPEZ v DANNY VEGA: 0.20280513821433432
# 	assertion JESSIE LOPEZ v MARK MCLOUGHLIN: 0.0697653306704189
# 	assertion JESSIE LOPEZ v JANNELLE WELKER: 0.24352049384957564
# 	assertion JESSIE LOPEZ v JEFFREY KATZ: 0.1212836457718669
# 	assertion JESSIE LOPEZ v WRITE_IN: 0.30520630021333583
# margins in contest MESA WATER DISTRICT
# Director, Division 2:
# 	assertion JAMES R. FISLER v ADAM C. ERETH: 0.12556354916067147
# 	assertion JAMES R. FISLER v WRITE_IN: 0.4914148681055155
# margins in contest CITY OF HUNTINGTON BEACH
# City Clerk:
# 	assertion ROBIN ESTANISLAU v WRITE_IN: 0.6288545794204623
# margins in contest CITY OF HUNTINGTON BEACH
# City Treasurer:
# 	assertion ALISA BACKSTROM v WRITE_IN: 0.6246659573933366
# margins in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 1, Short Term:
# 	assertion AL NEDERHOOD v FRED R. SMITH: 0.33328006723365466
# 	assertion AL NEDERHOOD v SCOTT HUPP: 0.3269828305605369
# 	assertion AL NEDERHOOD v WRITE_IN: 0.4827920905760432
# margins in contest CITY OF WESTMINSTER
# Member, City Council, District 2:
# 	assertion CARLOS MANZO v NAMQUAN NGUYEN: 0.09378343040532511
# 	assertion CARLOS MANZO v TRUNG TA: 0.23368596220135496
# 	assertion CARLOS MANZO v WRITE_IN: 0.4035421371686676
# margins in contest BUENA PARK LIBRARY DISTRICT
# Trustee:
# 	assertion PATRICIA GANER v DENNIS LEE SALTS: 0.33117362887183854
# 	assertion PATRICIA GANER v WRITE_IN: 0.598408638817846
# 	assertion IRENE CASTANEDA v DENNIS LEE SALTS: 0.10233020744529697
# 	assertion IRENE CASTANEDA v WRITE_IN: 0.36956521739130443
# 	assertion L CAROLE JENSEN v DENNIS LEE SALTS: 0.01838590508667237
# 	assertion L CAROLE JENSEN v WRITE_IN: 0.28562091503267983
# margins in contest CITY OF GARDEN GROVE
# Member, City Council, District 6:
# 	assertion KIM BERNICE NGUYEN v HUAN C. NGUYEN: 0.44949015888072097
# 	assertion KIM BERNICE NGUYEN v WRITE_IN: 0.6611335072326299
# margins in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 7:
# 	assertion MEGAN YOO SCHNEIDER v DEBBIE NEEV: 0.10792234855408922
# 	assertion MEGAN YOO SCHNEIDER v WRITE_IN: 0.41328451828214186
# margins in contest SANTA MARGARITA WATER DISTRICT
# Director:
# 	assertion CHARLES "CHUCK" GIBSON v WARREN MARTIN: 0.16150001007800374
# 	assertion CHARLES "CHUCK" GIBSON v WRITE_IN: 0.46979622276419497
# 	assertion BETTY H. OLSON v WARREN MARTIN: 0.13527704432306042
# 	assertion BETTY H. OLSON v WRITE_IN: 0.44357325700925165
# 	assertion FRANK URY v WARREN MARTIN: 0.05817023763932849
# 	assertion FRANK URY v WRITE_IN: 0.3664664503255195
# margins in contest CITY OF HUNTINGTON BEACH
# Member, City Council:
# KAMALA D. HARRIS v ROQUE "ROCKY" DE LA FUENTE GUERRA
# KANYE OMARI WEST: 0.5235393290035031
# 	assertion JOSEPH R. BIDEN
# KAMALA D. HARRIS v HOWIE HAWKINS
# ANGELA NICOLE WALKER: 0.5228053316019186
# 	assertion JOSEPH R. BIDEN
# KAMALA D. HARRIS v DONALD J. TRUMP
# MICHAEL R. PENCE: 0.08901092718422432
# 	assertion JOSEPH R. BIDEN
# KAMALA D. HARRIS v JO JORGENSEN
# JEREMY "SPIKE" COHEN: 0.5153502460993049
# 	assertion JOSEPH R. BIDEN
# KAMALA D. HARRIS v WRITE_IN: 0.520557424141207
# margins in contest UNITED STATES REPRESENTATIVE
# 45th District:
# 	assertion KATIE PORTER v GREG RATHS: 0.06757054880681923
# margins in contest STATE SENATOR
# 37th District:
# 	assertion DAVE MIN v JOHN M. W. MOORLACH: 0.02208746563616093
# margins in contest MEMBER OF THE STATE ASSEMBLY
# 68th District:
# 	assertion STEVEN "STEVE" CHOI v MELISSA FOX: 0.058893480393614084
# margins in contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion JOHN ORTEGA v TIGER KENNEDY COSMOS: 0.07165557301506031
# 	assertion JOHN ORTEGA v WRITE_IN: 0.45055527110295035
# margins in contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assertion ANA PAGE v ALEXIA DELIGIANNI-BRYDGES: 0.12933667614188105
# 	assertion ANA PAGE v WRITE_IN: 0.47247479651830004
# margins in contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 6:
# 	assertion ANGIE SCHLUETER-RUMSEY v APRIL BRASWELL: 0.31759918077649685
# 	assertion ANGIE SCHLUETER-RUMSEY v ALEX MUÑOZ: 0.3098130263599286
# 	assertion ANGIE SCHLUETER-RUMSEY v CARRIE LUNDELL: 0.06950158018326591
# 	assertion ANGIE SCHLUETER-RUMSEY v WRITE_IN: 0.37543918501385964
# margins in contest CITY OF ORANGE
# Mayor:
# 	assertion MARK A MURPHY v ADRIENNE GLADSON: 0.16928446771378702
# 	assertion MARK A MURPHY v WRITE_IN: 0.5327299080072174
# margins in contest CITY OF ORANGE
# City Clerk:
# 	assertion PAMELA COLEMAN v WRITE_IN: 0.7461028781021681
# margins in contest MEMBER OF THE STATE ASSEMBLY
# 73rd District:
# 	assertion LAURIE DAVIES v SCOTT RHINEHART: 0.16196409823933355
# margins in contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 1:
# 	assertion CAROLYN INMON v HELEN LOCKE: 0.13152965324701893
# 	assertion CAROLYN INMON v AARTI KAUSHAL: 0.23639704167279696
# 	assertion CAROLYN INMON v WRITE_IN: 0.3452637698217611
# 	assertion CAROLYN INMON v MATT WAID: 0.2797689748843619
# margins in contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 6:
# 	assertion JAMES R. WRIGHT v RYAN DACK: 0.13004403041579504
# 	assertion JAMES R. WRIGHT v WRITE_IN: 0.42806750612729716
# margins in contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7:
# 	assertion TIMOTHY "TIM" JEMAL v MO ENTEZAMPOUR: 0.16370199984928457
# 	assertion TIMOTHY "TIM" JEMAL v SEAN GAWNE: 0.24530898442966786
# 	assertion TIMOTHY "TIM" JEMAL v WRITE_IN: 0.37226514420230306
# margins in contest SADDLEBACK VALLEY UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion EDWARD WONG v TRICIA YEE: 0.0663283232480969
# 	assertion EDWARD WONG v WRITE_IN: 0.42525863751707993
# margins in contest CITY OF LAGUNA HILLS
# Member, City Council:
# 	assertion JANINE HEFT v NICK WOOD: 0.381307468042162
# 	assertion JANINE HEFT v WRITE_IN: 0.5244449428122897
# 	assertion BILL HUNT v NICK WOOD: 0.3505830903790088
# 	assertion BILL HUNT v WRITE_IN: 0.49372056514913654
# margins in contest UNITED STATES REPRESENTATIVE
# 48th District:
# 	assertion MICHELLE STEEL v HARLEY ROUDA: 0.020469082111408188
# margins in contest MEMBER OF THE STATE ASSEMBLY
# 74th District:
# 	assertion COTTIE PETRIE-NORRIS v DIANE DIXON: 0.009365225788783293
# margins in contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assertion CAROL CRANE v CHARLES KENT BOOKER: 0.24685758006339498
# 	assertion CAROL CRANE v WRITE_IN: 0.5313695485845447
# margins in contest CITY OF NEWPORT BEACH
# Member, City Council, District 2:
# 	assertion BRAD AVERY v WRITE_IN: 0.5073128763980499
# 	assertion BRAD AVERY v NANCY SCARBROUGH: 0.1679810725552051
# margins in contest CITY OF NEWPORT BEACH
# Member, City Council, District 5:
# 	assertion NOAH BLOM v JEFF HERDMAN: 0.16445010037281338
# 	assertion NOAH BLOM v WRITE_IN: 0.5055025810151994
# margins in contest CITY OF NEWPORT BEACH
# Member, City Council, District 7:
# 	assertion WILL O'NEILL v WRITE_IN: 0.7028785488958991
# margins in contest UNITED STATES REPRESENTATIVE
# 39th District:
# 	assertion YOUNG KIM v GIL CISNEROS: 0.04383334735835098
# margins in contest STATE SENATOR
# 29th District:
# 	assertion JOSH NEWMAN v LING LING CHANG: 0.03055496782705025
# margins in contest MEMBER OF THE STATE ASSEMBLY
# 55th District:
# 	assertion PHILLIP CHEN v ANDREW E. RODRIGUEZ: 0.1649463237105373
# margins in contest NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 4:
# 	assertion EVANGELINA REA ROSALES v MIGUEL ALVAREZ: 0.12088156310769516
# 	assertion EVANGELINA REA ROSALES v WRITE_IN: 0.47535882952125186
# margins in contest LA HABRA CITY SCHOOL DISTRICT
# Governing Board Member,
# Full Term:
# 	assertion SUSAN M. PRITCHARD v JOHN DOBSON: 0.12823663653120332
# 	assertion SUSAN M. PRITCHARD v WRITE_IN: 0.443254630035987
# 	assertion OFELIA CORONA HANSON v JOHN DOBSON: 0.12139032739401379
# 	assertion OFELIA CORONA HANSON v WRITE_IN: 0.43640832089879744
# margins in contest CITY OF LA HABRA
# Member, City Council:
# 	assertion ROSE ESPINOZA v PETER CRUZ: 0.2655957354848004
# 	assertion ROSE ESPINOZA v MICHAEL NAVARRO: 0.3467800028814292
# 	assertion ROSE ESPINOZA v WRITE_IN: 0.5492004034000864
# 	assertion TIM SHAW v PETER CRUZ: 0.1531479613888489
# 	assertion TIM SHAW v MICHAEL NAVARRO: 0.23433222878547766
# 	assertion TIM SHAW v WRITE_IN: 0.43675262930413483
# 	assertion STEVE SIMONIAN v PETER CRUZ: 0.14014551217403826
# 	assertion STEVE SIMONIAN v MICHAEL NAVARRO: 0.22132977957066702
# 	assertion STEVE SIMONIAN v WRITE_IN: 0.4237501800893244
# margins in contest COSTA MESA SANITARY DISTRICT
# Director, Division 2:
# 	assertion BRETT ECKLES v WRITE_IN: 0.44763742940882123
# 	assertion BRETT ECKLES v JAMES FERRYMAN: 0.06798198584602178
# margins in contest UNITED STATES REPRESENTATIVE
# 46th District:
# 	assertion LOU CORREA v JAMES S. WATERS: 0.3639503667533346
# margins in contest MEMBER OF THE STATE ASSEMBLY
#
# 	assertion GEORGE WEISS v STEVE DICTEROW: 0.12784346677870473
# margins in contest CITY OF LAGUNA BEACH
# City Clerk:
# 	assertion ANN MARIE MCKAY v MARIANN TRACY: 0.025508672948802547
# 	assertion ANN MARIE MCKAY v WRITE_IN: 0.39487425724746417
# margins in contest CITY OF LAGUNA BEACH
# City Treasurer:
# 	assertion LAURA PARISI v WRITE_IN: 0.6760098433467379
# margins in contest TUSTIN UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion JAMES H. LAIRD v SUSAN M. STOCKS: 0.2039511911679257
# 	assertion JAMES H. LAIRD v WRITE_IN: 0.4802763251339661
# margins in contest CITY OF MISSION VIEJO
# Member, City Council,
# Two-Year Term:
# 	assertion PATRICIA "TRISH" KELLEY v CATHY SCHLICHT: 0.27713253870021526
# 	assertion PATRICIA "TRISH" KELLEY v RYAN TWOREK: 0.36487563370013065
# 	assertion PATRICIA "TRISH" KELLEY v MICHAEL MCCONNELL: 0.37292934773393926
# 	assertion PATRICIA "TRISH" KELLEY v STEVE SIPE: 0.36575730344698965
# 	assertion PATRICIA "TRISH" KELLEY v JESSICA GILBERT: 0.3426473829668186
# 	assertion PATRICIA "TRISH" KELLEY v PAULINE HALE: 0.29652927313111443
# 	assertion PATRICIA "TRISH" KELLEY v WRITE_IN: 0.43581613794740504
# 	assertion BRIAN GOODELL v CATHY SCHLICHT: 0.260058664948541
# 	assertion BRIAN GOODELL v RYAN TWOREK: 0.3478017599484562
# 	assertion BRIAN GOODELL v MICHAEL MCCONNELL: 0.3558554739822648
# 	assertion BRIAN GOODELL v STEVE SIPE: 0.3486834296953152
# 	assertion BRIAN GOODELL v JESSICA GILBERT: 0.3255735092151444
# 	assertion BRIAN GOODELL v PAULINE HALE: 0.2794553993794402
# 	assertion BRIAN GOODELL v WRITE_IN: 0.4187422641957306
# margins in contest UNITED STATES REPRESENTATIVE
# 49th District:
# 	assertion BRIAN MARYOTT v MIKE LEVIN: 0.11889719095810092
# margins in contest CAPISTRANO UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion PAMELA BRAUNSTEIN v JIM REARDON: 0.10261420649590702
# 	assertion PAMELA BRAUNSTEIN v WRITE_IN: 0.45872722471613425
# margins in contest RANCHO SANTIAGO COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7:
# 	assertion TINA ARIAS MILLER v LORETTA SANCHEZ: 0.07739621983713918
# 	assertion TINA ARIAS MILLER v WRITE_IN: 0.4669920561794956
# margins in contest CITY OF ORANGE
# Member, City Council, District 1:
# 	assertion ARIANNA BARRIOS v DAVID VAZQUEZ: 0.12986445124617396
# 	assertion ARIANNA BARRIOS v EUGENE W. FIELDS: 0.19833843463052037
# 	assertion ARIANNA BARRIOS v WRITE_IN: 0.3544381285526892
# 	assertion ARIANNA BARRIOS v CHRISTIAN L. VAUGHAN: 0.22466112811543515
# margins in contest UNITED STATES REPRESENTATIVE
# 38th District:
# 	assertion LINDA T. SÁNCHEZ v MICHAEL TOLAR: 0.2838334717115407
# margins in contest CITY OF LA PALMA
# Member, City Council:
# 	assertion MARSHALL GOODMAN v APRIL KAMILAH BAGASAO BAUTISTA: 0.2540623888032263
# 	assertion MARSHALL GOODMAN v WRITE_IN: 0.5518918277784368
# 	assertion MARSHALL GOODMAN v TAYLOR H.W. QUAN: 0.3417150990392599
UNTINGTON BEACH UNION HIGH SCHOOL DISTRICT
# Governing Board Member:
# 	assertion SUSAN HENRY v SPENCER HAGAMAN: 0.1524044554125259
# 	assertion SUSAN HENRY v SAUL LANKSTER: 0.15104826696903006
# 	assertion SUSAN HENRY v CLAUDIA RAMOS: 0.24774339136041257
# 	assertion SUSAN HENRY v CHRISTINE HERNANDEZ: 0.16962360212543626
# 	assertion SUSAN HENRY v WRITE_IN: 0.3574390271015362
# 	assertion MICHAEL SIMONS v SPENCER HAGAMAN: 0.11401987594210627
# 	assertion MICHAEL SIMONS v SAUL LANKSTER: 0.11266368749861044
# 	assertion MICHAEL SIMONS v CLAUDIA RAMOS: 0.20935881188999317
# 	assertion MICHAEL SIMONS v CHRISTINE HERNANDEZ: 0.13123902265501686
# 	assertion MICHAEL SIMONS v WRITE_IN: 0.3190544476311168
# margins in contest SOUTH COAST WATER DISTRICT
# Director:
# 	assertion RICK ERKENEFF v MARKUS J. LENGER: 0.09775015875895865
# 	assertion RICK ERKENEFF v WAYNE RAYFIELD: 0.07661253742175456
# 	assertion RICK ERKENEFF v WRITE_IN: 0.3618797060691281
# 	assertion SCOTT GOLDMAN v MARKUS J. LENGER: 0.04839880250385553
# 	assertion SCOTT GOLDMAN v WAYNE RAYFIELD: 0.027261181166651438
# 	assertion SCOTT GOLDMAN v WRITE_IN: 0.3125283498140252
# 	assertion DOUGLAS ERDMAN v MARKUS J. LENGER: 0.0298013245033113
# 	assertion DOUGLAS ERDMAN v WAYNE RAYFIELD: 0.008663703166107206
# 	assertion DOUGLAS ERDMAN v WRITE_IN: 0.293930871813481
# margins in contest CITY OF GARDEN GROVE
# Member, City Council, District 5:
# 	assertion STEPHANIE KLOPFENSTEIN v ROBERT TUCKER: 0.3685771613015789
# 	assertion STEPHANIE KLOPFENSTEIN v WRITE_IN: 0.6272354531972433
# margins in contest NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7:
# 	assertion RYAN BENT v KERI KROPKE: 0.0886056877393433
# 	assertion RYAN BENT v WRITE_IN: 0.4593257580513528
# margins in contest CITY OF DANA POINT
# Member, City Council, District 4:
# 	assertion MIKE FROST v GARY NEWKIRK: 0.2181769864469838
# 	assertion MIKE FROST v WRITE_IN: 0.5633802816901408
# margins in contest PLACENTIA-YORBA LINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1:
# 	assertion SHAWN YOUNGBLOOD v PAOLING GUO: 0.25232756031634795
# 	assertion SHAWN YOUNGBLOOD v ERIC PADGET: 0.041946140754830274
# 	assertion SHAWN YOUNGBLOOD v WRITE_IN: 0.3803684052457703
# margins in contest CITY OF ORANGE
# Member, City Council, District 2:
# 	assertion JON DUMITRU v DANIEL CORREA: 0.21238339867513867
# 	assertion JON DUMITRU v MARTIN VARONA: 0.16547248884682975
# 	assertion JON DUMITRU v WRITE_IN: 0.35636068676490473
# 	assertion JON DUMITRU v CAROLINE ALATORRE: 0.19007705826686494
# margins in contest SUNSET BEACH SANITARY DISTRICT
# Director, Full Term:
# 	assertion DAVID EVANS v GRAHAM HOAD: 0.24720357941834448
# 	assertion DAVID EVANS v WRITE_IN: 0.5413870246085011
# 	assertion JOHN H. WOODS v GRAHAM HOAD: 0.1778523489932886
# 	assertion JOHN H. WOODS v WRITE_IN: 0.4720357941834452
# 	assertion JON H. REGNIER v GRAHAM HOAD: 0.11633109619686799
# 	assertion JON H. REGNIER v WRITE_IN: 0.4105145413870246
# margins in contest SURFSIDE COLONY STORM WATER PROTECTION DISTRICT
# Trustee:
# 	assertion DAVE CHAMBERLAIN v LINDA GAROFALO: 0.13310580204778155
# 	assertion DAVE CHAMBERLAIN v WRITE_IN: 0.5324232081911262
# 	assertion VICTOR J. KRISS v LINDA GAROFALO: 0.12627986348122877
# 	assertion VICTOR J. KRISS v WRITE_IN: 0.5255972696245734
# margins in contest CITY OF COSTA MESA
# Mayor:
# 	assertion KATRINA FOLEY v QUENTIN "Q" PULLEN: 0.38226435316074436
# 	assertion KATRINA FOLEY v AL MELONE: 0.4486944952602694
# 	assertion KATRINA FOLEY v WENDY BROOKS LEECE: 0.3712696564850231
# 	assertion KATRINA FOLEY v SANDRA L. "SANDY" GENIS: 0.2712456344586729
# 	assertion KATRINA FOLEY v WRITE_IN: 0.473973058373524
# margins in contest COSTA MESA SANITARY DISTRICT
# Director, Division 4:
# 	assertion ART PERRY v MICHELLE FIGUEREDO-WILSON: 0.3475477430555556
# 	assertion ART PERRY v WRITE_IN: 0.6072048611111112
# margins in contest RANCHO SANTIAGO COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assertion SAL TINAJERO v MIKE GONZALEZ: 0.23389814857564994
# 	assertion SAL TINAJERO v WRITE_IN: 0.5558428366960617
# margins in contest CITY OF SANTA ANA
# Member, City Council, Ward 5:
# 	assertion JOHNATHAN RYAN HERNANDEZ v JUAN VILLEGAS: 0.08198480107286543
# 	assertion JOHNATHAN RYAN HERNANDEZ v LAURA PEREZ: 0.19418864550737602
# 	assertion JOHNATHAN RYAN HERNANDEZ v WRITE_IN: 0.3657577112203845
# 	assertion JOHNATHAN RYAN HERNANDEZ v VIC MENDEZ: 0.3148860080464908
# margins in contest CITY OF FULLERTON
# Member, City Council, District 1:
# 	assertion FRED JUNG v ANDREW CHO: 0.0232030449421754
# 	assertion FRED JUNG v WRITE_IN: 0.46318255013907184
# margins in contest COAST COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion JERRY PATTERSON v TONY BUI: 0.19672867799047355
# 	assertion JERRY PATTERSON v LONG PHAM: 0.25739192954075674
# 	assertion JERRY PATTERSON v WRITE_IN: 0.43354003774602323
# margins in contest GARDEN GROVE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5:
# 	assertion DINA NGUYEN v SAMANTHA BAO ANH NGUYEN: 0.3790780442335395
# 	assertion DINA NGUYEN v PATRICK CAHILL: 0.38162020167782384
# 	assertion DINA NGUYEN v WRITE_IN: 0.5397000254215745
# margins in contest COAST COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 4:
# 	assertion MARY HORNBUCKLE v MICHAEL B COLLIER: 0.36026786375690767
# 	assertion MARY HORNBUCKLE v WRITE_IN: 0.5736254944664207
# margins in contest CAPISTRANO UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assertion LISA DAVIS v SUE HILL: 0.015787459335331988
# 	assertion LISA DAVIS v WRITE_IN: 0.3619633858518849
# 	assertion LISA DAVIS v ADRIENNE M. SILVA: 0.2625821266824009
# margins in contest CITY OF BREA
# Member, City Council:
# 	assertion CHRISTINE MARICK v TYLER BAUGH: 0.22492542517336234
# 	assertion CHRISTINE MARICK v WRITE_IN: 0.5025762212838492
# 	assertion CHRISTINE MARICK v ROBYN NEUFELD: 0.34819664510130544
# 	assertion MARTY SIMONOFF v TYLER BAUGH: 0.16410335877271143
# 	assertion MARTY SIMONOFF v WRITE_IN: 0.44175415488319847
# 	assertion MARTY SIMONOFF v ROBYN NEUFELD: 0.28737457870065475
# margins in contest CITY OF BREA
# City Treasurer:
# 	assertion DENISE EBY v BEV PERRY: 0.059194979274009185
# 	assertion DENISE EBY v WRITE_IN: 0.45202029984891334
# margins in contest PLACENTIA-YORBA LINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assertion LEANDRA BLADES v SUSAN METCALF: 0.04325418737345843
# 	assertion LEANDRA BLADES v MISTY JANSSEN: 0.17922878704214984
# 	assertion LEANDRA BLADES v MIKE NICOSIA: 0.26247009018958223
# 	assertion LEANDRA BLADES v WRITE_IN: 0.34189214062212403
# margins in contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1:
# 	assertion LEAH ERSOYLU v VICKI SNELL: 0.04877548228211803
# 	assertion LEAH ERSOYLU v WRITE_IN: 0.45402927897113154
# margins in contest CITY OF COSTA MESA
# Member, City Council, District 1:
# 	assertion DON HARPER v JOHN STEPHENS: 0.02813701502971
# 	assertion DON HARPER v WRITE_IN: 0.384743096819294
# 	assertion DON HARPER v JASON KOMALA: 0.24432016777350585
# margins in contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 6:
# 	assertion KRISTA WEIGAND v AMY PETERS: 0.10383283441920521
# 	assertion KRISTA WEIGAND v XENO RALF MULLER II: 0.36115513294594126
# 	assertion KRISTA WEIGAND v ALEXIS ZAVOURIS: 0.39114867641016615
# 	assertion KRISTA WEIGAND v WRITE_IN: 0.4229030932675941
# margins in contest CITY OF COSTA MESA
# Member, City Council, District 6:
# 	assertion JEFFREY HARLAN v LEE RAMOS: 0.29221641724962355
# 	assertion JEFFREY HARLAN v HENGAMEH ABRAHAM: 0.239263260426813
# 	assertion JEFFREY HARLAN v JEFF PETTIS: 0.23173647392189856
# 	assertion JEFFREY HARLAN v WRITE_IN: 0.4047640131054635
# margins in contest CITY OF FULLERTON
# Member, City Council, District 2:
# 	assertion NICK DUNLAP v CHUCK SARGEANT: 0.35531903159984557
# 	assertion NICK DUNLAP v WRITE_IN: 0.44857442232393985
# 	assertion NICK DUNLAP v FAISAL QAZI: 0.18794463133513473
# 	assertion NICK DUNLAP v MACKENZIE CHANG: 0.34473060166547187
# margins in contest ROSSMOOR COMMUNITY SERVICES DISTRICT
# Director, Full Term:
# 	assertion JEFFREY BARKE v MICHAEL MAYNARD: 0.08195592286501374
# 	assertion JEFFREY BARKE v JOYCE BLOOM: 0.2808539944903581
# 	assertion JEFFREY BARKE v WRITE_IN: 0.4387052341597797
# 	assertion TONY DEMARCO v MICHAEL MAYNARD: 0.0625344352617081
# 	assertion TONY DEMARCO v JOYCE BLOOM: 0.26143250688705244
# 	assertion TONY DEMARCO v WRITE_IN: 0.4192837465564738
# 	assertion NATHAN SEARLES v MICHAEL MAYNARD: 0.038567493112947604
# 	assertion NATHAN SEARLES v JOYCE BLOOM: 0.23746556473829195
# 	assertion NATHAN SEARLES v WRITE_IN: 0.39531680440771355
# margins in contest CITY OF GARDEN GROVE
# Member, City Council, District 2:
# 	assertion JOHN R. O'NEILL v JULIE DIEP: 0.06387475538160459
# 	assertion JOHN R. O'NEILL v WRITE_IN: 0.47741682974559696
# margins in contest CITY OF FULLERTON
# Member, City Council, District 4:
# 	assertion BRUCE WHITAKER v AARUNI THAKUR: 0.02372558361124355
# 	assertion BRUCE WHITAKER v WRITE_IN: 0.464506908051453
# margins in contest FOUNTAIN VALLEY SCHOOL DISTRICT
# Governing Board Member:
# 	assertion STEVE SCHULTZ v TOM NGUYEN: 0.27546144196881905
# 	assertion STEVE SCHULTZ v IAN COLLINS: 0.22621109850068688
# 	assertion STEVE SCHULTZ v WRITE_IN: 0.4861716743324771
# 	assertion JEANNE GALINDO v TOM NGUYEN: 0.15160384684307981
# 	assertion JEANNE GALINDO v IAN COLLINS: 0.10235350337494764
# 	assertion JEANNE GALINDO v WRITE_IN: 0.36231407920673786
# margins in contest CITY OF FOUNTAIN VALLEY
# Member, City Council:
# 	assertion GLENN GRANDIS v MAI KHANH TRAN: 0.06691643890304944
# 	assertion GLENN GRANDIS v JIM CUNNEEN: 0.11052421459939188
# 	assertion GLENN GRANDIS v MARY PHAM: 0.23514418204710874
# 	assertion GLENN GRANDIS v TOM NGUYEN: 0.21192764794398555
# 	assertion GLENN GRANDIS v CHERYL BROTHERS: 0.05979178822590048
# 	assertion GLENN GRANDIS v WRITE_IN: 0.3183674722844947
# 	assertion TED BUI v MAI KHANH TRAN: 0.02923563553726627
# 	assertion TED BUI v JIM CUNNEEN: 0.07284341123360871
# 	assertion TED BUI v MARY PHAM: 0.19746337868132535
# 	assertion TED BUI v TOM NGUYEN: 0.17424684457820216
# 	assertion TED BUI v CHERYL BROTHERS: 0.02211098486011731
# 	assertion TED BUI v WRITE_IN: 0.2806866689187115
# margins in contest CITY OF COSTA MESA
# Member, City Council, District 2:
# 	assertion LOREN GAMEROS v BEN CHAPMAN: 0.16475923126754477
# 	assertion LOREN GAMEROS v WRITE_IN: 0.4230187864392141
# 	assertion LOREN GAMEROS v GARY PARKIN: 0.25199740876700494
# margins in contest IRVINE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5:
# 	assertion PAUL BOKOTA v DEMETRA ARVANITIDIS: 0.34503483857241646
# 	assertion PAUL BOKOTA v WRITE_IN: 0.5849688846337961
# margins in contest PLACENTIA-YORBA LINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion MARILYN ANDERSON v LASHÉ RODRIGUEZ: 0.035292782569223746
# 	assertion MARILYN ANDERSON v JOSHUA CORREA: 0.09067181116659095
# 	assertion MARILYN ANDERSON v WRITE_IN: 0.32784838856105303
# margins in contest CITY OF ORANGE
# Member, City Council, District 5:
# 	assertion ANA GUTIERREZ v RICK LEDESMA: 0.051645676791194806
# 	assertion ANA GUTIERREZ v WRITE_IN: 0.4675627050481532
# margins in contest CITY OF ANAHEIM
# Member, City Council, District 1:
# 	assertion JOSE DIAZ v RYAN BALIUS: 0.20612702366127023
# 	assertion JOSE DIAZ v DENISE BARNES: 0.03965130759651303
# 	assertion JOSE DIAZ v WRITE_IN: 0.38181818181818183
# margins in contest CITY OF PLACENTIA
# City Clerk, Short Term:
# 	assertion ROBERT S. "BOB" MCKINNELL v WRITE_IN: 0.7604119850187265
# margins in contest CITY OF PLACENTIA
# City Treasurer:
# 	assertion KEVIN A. LARSON v WRITE_IN: 0.7491760299625467
# margins in contest WESTMINSTER SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1:
# 	assertion DAVID JOHNSON v ANGEL RAMIREZ: 0.23773974962673705
# 	assertion DAVID JOHNSON v WRITE_IN: 0.5265878029171931
# margins in contest CITY OF LOS ALAMITOS
# Member, City Council, District 1:
# 	assertion TANYA DOBY v DEAN GROSE: 0.014272970561998166
# 	assertion TANYA DOBY v WRITE_IN: 0.4576271186440677
# margins in contest CITY OF LAGUNA WOODS
# Member, City Council:
# 	assertion NOEL HATCH v JUDITH P. TROUTMAN: 0.17024960323185678
# 	assertion NOEL HATCH v WRITE_IN: 0.4537584764103304
# 	assertion NOEL HATCH v KATHRYN ROBBINS: 0.172341653441062
# 	assertion SHARI L HORNE v JUDITH P. TROUTMAN: 0.1395902467176453
# 	assertion SHARI L HORNE v WRITE_IN: 0.4230991198961189
# 	assertion SHARI L HORNE v KATHRYN ROBBINS: 0.1416822969268503
# 	assertion CYNTHIA CONNERS v JUDITH P. TROUTMAN: 0.13064492858173415
# 	assertion CYNTHIA CONNERS v WRITE_IN: 0.4141538017602078
# 	assertion CYNTHIA CONNERS v KATHRYN ROBBINS: 0.13273697879093915
# margins in contest CITY OF BUENA PARK
# Member, City Council, District 3:
# 	assertion SUSAN SONNE v PAUL D. GONZALES: 0.3000753012048192
# 	assertion SUSAN SONNE v SHARON SMITH: 0.1843624497991967
# 	assertion SUSAN SONNE v WRITE_IN: 0.46460843373493965
# margins in contest CITY OF BUENA PARK
# Member, City Council, District 4:
# 	assertion ARTHUR C. BROWN v DONNA VARONA SIPL: 0.16483516483516492
# 	assertion ARTHUR C. BROWN v WRITE_IN: 0.5185279836442627
# margins in contest CITY OF PLACENTIA
# Member, City Council, District 3:
# 	assertion JEREMY B. YAMAGUCHI v WRITE_IN: 0.762995152933311
# margins in contest CITY OF ORANGE
# Member, City Council, District 3:
# 	assertion MIKE ALVAREZ v JOHN R RUSSO: 0.2089720832660964
# 	assertion MIKE ALVAREZ v DANETT ABBOTT-WICKER: 0.24753913183798604
# 	assertion MIKE ALVAREZ v WRITE_IN: 0.43868000645473626
# margins in contest LOS ALAMITOS UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5:
# 	assertion MEG CUTULI v MATT FILLER: 0.20284451808892578
# 	assertion MEG CUTULI v WRITE_IN: 0.5057995028997515
# margins in contest CITY OF SEAL BEACH
# Member, City Council, District 2:
# 	assertion THOMAS MOORE v CAROLE S. DAMOCI: 0.34296516338104244
# 	assertion THOMAS MOORE v WRITE_IN: 0.6178773967053741
# margins in contest CITY OF SEAL BEACH
# Member, City Council, District 4:
# 	assertion SCHELLY SUSTARSIC v WRITE_IN: 0.7356963438459392
# margins in contest BREA OLINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5:
# 	assertion LAUREN BARNES v GAIL LYONS: 0.00024015369836694056
# 	assertion LAUREN BARNES v WRITE_IN: 0.4301152737752161
# margins in contest LOS ALAMITOS UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2:
# 	assertion CHRIS FOREHAN v PAURVI TRIVEDI: 0.04650482597250649
# 	assertion CHRIS FOREHAN v JODY L. ROUBANIS: 0.22199473530272007
# 	assertion CHRIS FOREHAN v WRITE_IN: 0.37584088914887404
# margins in contest TUSTIN UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1:
# 	assertion ALLYSON M. DAMIKOLAS v KIRK O. HAHN: 0.3213999999999999
# 	assertion ALLYSON M. DAMIKOLAS v WRITE_IN: 0.41626666666666656
# 	assertion ALLYSON M. DAMIKOLAS v TAMMIE K. BULLARD: 0.08099999999999996
# margins in contest ANAHEIM ELEMENTARY SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3:
# 	assertion JOSE PAOLO MAGCALAS v LUCILLE KRING: 0.260010642543568
# 	assertion JOSE PAOLO MAGCALAS v WRITE_IN: 0.5844751895703073
# margins in contest CITY OF DANA POINT
# Member, City Council, District 5:
# 	assertion MICHAEL VILLAR v WRITE_IN: 0.6909090909090909
# 	assertion MICHAEL VILLAR v BENJAMIN TYLER BEBEE: 0.5454545454545454
# margins in contest BUENA PARK SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 4:
# 	assertion IRENE CASTANEDA v L CAROLE JENSEN: 0.3921913471684839
# 	assertion IRENE CASTANEDA v WRITE_IN: 0.6285613788251847
# margins in contest CITY OF PLACENTIA
# Member, City Council, District 1:
# 	assertion RHONDA SHADER v DEVON GRAY: 0.05994754589733975
# 	assertion RHONDA SHADER v WRITE_IN: 0.48707381041588604
# margins in contest CITY OF PLACENTIA
# Member, City Council, District 5:
# 	assertion WARD L. SMITH v HILAIRE FUJI SHIOURA: 0.2987032569360675
# 	assertion WARD L. SMITH v WRITE_IN: 0.5616706875753921
# margins in contest CITY OF LOS ALAMITOS
# Member, City Council, District 2:
# 	assertion RON BATES v KATE HALLMAN: 0.3172131147540984
# 	assertion RON BATES v WRITE_IN: 0.6114754098360655
# margins in contest CITY OF LAKE FOREST
# Member, City Council, District 5:
# 	assertion ROBERT PEQUEÑO v SHANE JONES: 0.4569652534268409
# 	assertion ROBERT PEQUEÑO v LARISSA CLARK: 0.38205291679948994
# 	assertion ROBERT PEQUEÑO v JEANNETTE J. NADAL: 0.33997449792795664
# 	assertion ROBERT PEQUEÑO v WRITE_IN: 0.49681224099458077
# 	assertion ROBERT PEQUEÑO v FRANK WAGONER: 0.4319413452343004
# margins in contest CITY OF SAN JUAN CAPISTRANO
# Member, City Council, District 5:
# 	assertion HOWARD HART v JOHN ALPAY: 0.2798165137614679
# 	assertion HOWARD HART v WRITE_IN: 0.570395201129146
# margins in contest CITY OF LOS ALAMITOS
# Member, City Council, District 3:
# 	assertion JORDAN B. NEFULDA v WRITE_IN: 0.6050156739811912
# margins in contest HUNTINGTON BEACH CITY SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1:
# 	assertion BRIDGET KAUB v ROGER S. NOOR: 0.3421558350803633
# 	assertion BRIDGET KAUB v WRITE_IN: 0.5146750524109014
# margins in contest SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT
# Director, Full Term:
# 	assertion JAMES GUZIAK v BHAVIN PATEL: 0.10739436619718301
# 	assertion JAMES GUZIAK v WRITE_IN: 0.42253521126760574
# 	assertion CRAIG S. SCHILL v BHAVIN PATEL: 0.03169014084507049
# 	assertion CRAIG S. SCHILL v WRITE_IN: 0.346830985915493
# margins in contest SILVERADO-MODJESKA RECREATION AND PARK DISTRICT
# Director:
# 	assertion MICHELE GRACE AGOPIAN v CELESTE GOFF VEERKAMP: 0.07982832618025748
# 	assertion MICHELE GRACE AGOPIAN v WRITE_IN: 0.45922746781115875
# 	assertion JULIE A. MORRIS v CELESTE GOFF VEERKAMP: 0.05836909871244633
# 	assertion JULIE A. MORRIS v WRITE_IN: 0.4377682403433476
# margins in contest CITY OF STANTON
# Member, City Council, District 2:
# 	assertion HONG ALYCE VAN v DEWAYNE ALLEN NORMAND: 0.03277591973244154
# 	assertion HONG ALYCE VAN v WRITE_IN: 0.47625418060200664
# margins in contest CAPISTRANO BAY COMMUNITY SERVICES DISTRICT
# Director:
# 	assertion BRAD L. JENKINS v YURI CRAMER: 0.35779816513761475
# 	assertion BRAD L. JENKINS v WRITE_IN: 0.6513761467889909
# 	assertion WILLIAM WIERSIG v YURI CRAMER: 0.201834862385321
# 	assertion WILLIAM WIERSIG v WRITE_IN: 0.49541284403669716
# CPU times: user 15min 31s, sys: 3.7 s, total: 15min 34s
# Wall time: 15min 39s

# %%
audit.write_audit_parameters(contests=contests)

# %% [markdown]
# ## Set up for sampling

# %% [markdown]
# ## Find initial sample size

# %%
# %%time
# find initial sample size 
# error here, there are some CVRs that aren't receiving a p, 
# which then causes an error when they are summed over. 
# See line 746-749 in Audit.py;
# one fix is to set the p for CVRs not in the contest to 0; 
# another is to skip counting them in the sum...
sample_size = audit.find_sample_size(contests, cvrs=cvr_list)  
print(f'{sample_size=}\n{[(i, c.sample_size) for i, c in contests.items()]}')
# Out:
# sample_size=20112
# [('Proposition 19', 94), ('Proposition 20', 39), ('Proposition 21', 19), ('Proposition 22', 19), ('Proposition 23', 18), ('Proposition 24', 78), ('Proposition 25', 28), ('AA-City of Orange', 23), ('Proposition 14', 78), ('Proposition 15', 29), ('Proposition 16', 19), ('Proposition 17', 1488), ('Proposition 18', 21), ('Z-City of Newport Beach', 67), ('CC-City of Tustin', 12), ('S-City of Fullerton', 42), ('U-City of Fullerton', 30), ('DD-City of Westminster', 11), ('Y-City of Los Alamitos', 329), ('Q-City of Costa Mesa', 20), ('P-City of Cypress', 17), ('BB-City of San Clemente', 11), ('W-City of La Habra', 17), ('X-City of La Habra', 12), ('V-City of Laguna Woods', 367), ('ORANGE COUNTY WATER DISTRICT\nDirector, Division 4', 31), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 3', 40), ('ORANGE COUNTY WATER DISTRICT\nDirector, Division 6', 35), ('CITY OF GARDEN GROVE\nMayor', 19), ('IRVINE RANCH WATER DISTRICT\nDirector, Division 4', 50), ('CITY OF WESTMINSTER\nMember, City Council, District 3', 22), ('MIDWAY CITY SANITARY DISTRICT\nDirector', 197), ('IRVINE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3', 32), ('CITY OF IRVINE\nMayor', 56), ('CITY OF IRVINE\nMember, City Council', 3930), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 4', 85), ('CITY OF TUSTIN\nMember, City Council', 423), ('EAST ORANGE COUNTY WATER DISTRICT\nDirector', 100), ('CITY OF SANTA ANA\nMember, City Council, Ward 3', 85), ('MESA WATER DISTRICT\nDirector, Division 2', 47), ('CITY OF HUNTINGTON BEACH\nCity Clerk', 8), ('CITY OF HUNTINGTON BEACH\nCity Treasurer', 9), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 1, Short Term', 17), ('CITY OF WESTMINSTER\nMember, City Council, District 2', 63), ('BUENA PARK LIBRARY DISTRICT\nTrustee', 327), ('CITY OF GARDEN GROVE\nMember, City Council, District 6', 12), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 7', 55), ('SANTA MARGARITA WATER DISTRICT\nDirector', 102), ('CITY OF HUNTINGTON BEACH\nMember, City Council', 104), ('CITY OF SANTA ANA\nMayor', 55), ('CITY OF SAN CLEMENTE\nMember, City Council, Full Term', 251), ('CITY OF SAN CLEMENTE\nMember, City Council, Short Term', 376), ('CITY OF SAN CLEMENTE\nCity Clerk', 8), ('CITY OF SAN CLEMENTE\nCity Treasurer', 8), ('CITY OF ORANGE\nCity Treasurer', 7), ('PRESIDENT AND VICE PRESIDENT', 66), ('UNITED STATES REPRESENTATIVE\n45th District', 88), ('STATE SENATOR\n37th District', 273), ('MEMBER OF THE STATE ASSEMBLY\n68th District', 101), ('ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 2', 83), ('ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3', 45), ('ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 6', 85), ('CITY OF ORANGE\nMayor', 34), ('CITY OF ORANGE\nCity Clerk', 7), ('MEMBER OF THE STATE ASSEMBLY\n73rd District', 36), ('SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT\nGoverning Board Member,\nTrustee Area 1', 45), ('SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT\nGoverning Board Member,\nTrustee Area 6', 45), ('SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT\nGoverning Board Member,\nTrustee Area 7', 36), ('SADDLEBACK VALLEY UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 2', 89), ('CITY OF LAGUNA HILLS\nMember, City Council', 16), ('UNITED STATES REPRESENTATIVE\n48th District', 294), ('MEMBER OF THE STATE ASSEMBLY\n74th District', 652), ('NEWPORT-MESA UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3', 23), ('CITY OF NEWPORT BEACH\nMember, City Council, District 2', 35), ('CITY OF NEWPORT BEACH\nMember, City Council, District 5', 35), ('CITY OF NEWPORT BEACH\nMember, City Council, District 7', 7), ('UNITED STATES REPRESENTATIVE\n39th District', 136), ('STATE SENATOR\n29th District', 196), ('MEMBER OF THE STATE ASSEMBLY\n55th District', 35), ('NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT\nGoverning Board Member,\nTrustee Area 4', 49), ('LA HABRA CITY SCHOOL DISTRICT\nGovernin ...
# CPU times: user 7min 19s, sys: 1.56 s, total: 7min 21s
# Wall time: 7min 21s

# %%
for con in contests:
    if contests[con].sample_size == contests[con].cvrs:
        name = con
        print(con)
# Out:
# BREA OLINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5

# %%
print(contests[name])
# Out:
# {'id': 'BREA OLINDA UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 5', 'name': 'BREA OLINDA UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 5', 'risk_limit': 0.05, 'cards': 4164, 'choice_function': 'PLURALITY', 'n_winners': 1, 'share_to_win': None, 'candidates': ['LAUREN BARNES', 'GAIL LYONS', 'WRITE_IN'], 'winner': ['LAUREN BARNES'], 'assertion_file': None, 'audit_type': 'BALLOT_COMPARISON', 'test': <function NonnegMean.alpha_mart at 0x7fb1c19cf040>, 'g': 0.1, 'estim': <function NonnegMean.optimal_comparison at 0x7fb1c19cf430>, 'use_style': True, 'assertions': {'LAUREN BARNES v GAIL LYONS': <Audit.Assertion object at 0x7fb19d704640>, 'LAUREN BARNES v WRITE_IN': <Audit.Assertion object at 0x7fb19d704730>}, 'tally': None, 'sample_size': 4164, 'cvrs': 4164, 'margins': {'LAUREN BARNES v GAIL LYONS': 0.00024015369836694056, 'LAUREN BARNES v WRITE_IN': 0.4301152737752161}}

# %%
print(contests['Proposition 19'])
# Out:
# {'id': 'Proposition 19', 'name': 'Proposition 19', 'risk_limit': 0.05, 'cards': 1546057, 'choice_function': 'PLURALITY', 'n_winners': 1, 'share_to_win': None, 'candidates': ['Yes', 'No'], 'winner': ['No'], 'assertion_file': None, 'audit_type': 'BALLOT_COMPARISON', 'test': <function NonnegMean.alpha_mart at 0x7fb1c19cf040>, 'g': 0.1, 'estim': <function NonnegMean.optimal_comparison at 0x7fb1c19cf430>, 'use_style': True, 'assertions': {'No v Yes': <Audit.Assertion object at 0x7fb1540f0940>}, 'tally': None, 'sample_size': 94, 'cvrs': 1546057, 'margins': {'No v Yes': 0.0630326048780867}}

# %%
without_style_sampling_frac = []
without_style_contest_size = []
for con in contests:
    without_style_contest_size.append(contests[con].cvrs)
    without_style_sampling_frac.append(contests[con].sample_size / contests[con].cvrs)
    
import matplotlib.pyplot as plt
plt.scatter(np.log10(without_style_contest_size), np.log10(without_style_sampling_frac))
plt.xlabel('log Contest Size')
plt.ylabel('log Sampling Fraction')
plt.title('Without Style')
# Out:
# Text(0.5, 1.0, 'Without Style')

# %%
# sampling_frac = []
# contest_size = []
# for con in contests:
#     contest_size.append(contests[con].cvrs)
#     sampling_frac.append(contests[con].sample_size / contests[con].cvrs)

# %%
plt.scatter(np.log10(contest_size), np.log10(sampling_frac))
plt.xlabel('log Contest Size')
plt.ylabel('log Sampling Fraction')
plt.title('With Style')
# Out:
# Text(0.5, 1.0, 'With Style')

# %% [markdown]
# ## Draw the first sample

# %%
# %%time
# draw the initial sample using consistent sampling
prng = SHA256(audit.seed)
CVR.assign_sample_nums(cvr_list, prng)
#sampled_cvr_indices needs to be an array for Hart.sample_from_cvrs?
#why are we subtracting 1 from it, i.e. `enumerate(sample-1)` in Hart.sample_from_cvrs
sampled_cvr_indices = CVR.consistent_sampling(cvr_list=cvr_list, contests=contests)
n_sampled_phantoms = np.sum(sampled_cvr_indices > manifest_cards)
print(f'The sample includes {n_sampled_phantoms} phantom cards.')

# %%
len(cvr_list), manifest_cards, audit.max_cards, len(sampled_cvr_indices)

# %%
cvr_dict = [{'id': "1_1", 'votes': {'AvB': {'Alice':True}}},
                    {'id': "1_2", 'votes': {'AvB': {'Bob':True}}},
                    {'id': "1_3", 'votes': {'AvB': {'Alice':True}}}]
manifest = pd.DataFrame.from_dict({'Container': ['Mail', 'Mail'], 'Tabulator': [1, 1],\
    'Batch Name': [1, 2], 'Number of Ballots': [1, 2]}, orient = "columns")
manifest, manifest_cards, phantoms = Hart.prep_manifest(manifest, 3, 3)
sample_indices = [0,1]
sampled_card_identifiers, sample_order, mvr_phantoms_sample = Hart.sample_from_manifest(manifest, sample_indices)

# %%
manifest
# Out:
#   Container Tabulator Batch Name Number of Ballots  cum_cards
# 0      Mail         1          1                 1          1
# 1      Mail         1          2                 2          3

# %%
sampled_card_identifiers
# Out:
# [['Mail', '1', '2', -3, '1-2--3'], ['Mail', '1', '1', 1, '1-1-1']]

# %%
# for comparison audit
cards_to_retrieve, sample_order, cvr_sample, mvr_phantoms_sample = \
    Hart.sample_from_cvrs(cvr_list, manifest, sampled_cvr_indices)

# for polling audit
# cards_to_retrieve, sample_order, mvr_phantoms_sample = Dominion.sample_from_manifest(manifest, sample)

# %%
# write the sample
#Dominion.write_cards_sampled(audit.sample_file, cards_to_retrieve, print_phantoms=False)

# %% [markdown]
# ## Read the audited sample data

# %%
# for real data
# with open(audit.mvr_file) as f:
#     mvr_json = json.load(f)

# mvr_sample = CVR.from_dict(mvr_json['ballots'])

# for simulated data, no errors
mvr_sample = cvr_sample

# %% [markdown]
# ## Find measured risks for all assertions

# %%
mvr_sample.sort(key = lambda x: sample_order[x.id]["selection_order"])

# %%
CVR.prep_comparison_sample(mvr_sample, cvr_sample, sample_order)  # for comparison audit
# CVR.prep_polling_sample(mvr_sample, sample_order)  # for polling audit

# %%
# %%time
p_max = Assertion.set_p_values(contests=contests, mvr_sample=mvr_sample, cvr_sample=cvr_sample)
print(f'maximum assertion p-value {p_max}')
done = audit.summarize_status(contests)
# Out:
# maximum assertion p-value 0.025112199214440918
#
# p-values for assertions in contest Proposition 19
# 	No v Yes: 3.8950800496326726e-252
#
# contest Proposition 19 AUDIT COMPLETE at risk limit 0.05. Attained risk 3.8950800496326726e-252
#
# p-values for assertions in contest Proposition 20
# 	No v Yes: 0.0
#
# contest Proposition 20 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest Proposition 21
# 	No v Yes: 1.119168913748306e-248
#
# contest Proposition 21 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.119168913748306e-248
#
# p-values for assertions in contest Proposition 22
# 	Yes v No: 1.0970012059104293e-138
#
# contest Proposition 22 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.0970012059104293e-138
#
# p-values for assertions in contest Proposition 23
# 	No v Yes: 3.029765618320665e-146
#
# contest Proposition 23 AUDIT COMPLETE at risk limit 0.05. Attained risk 3.029765618320665e-146
#
# p-values for assertions in contest Proposition 24
# 	Yes v No: 4.038201884126431e-25
#
# contest Proposition 24 AUDIT COMPLETE at risk limit 0.05. Attained risk 4.038201884126431e-25
#
# p-values for assertions in contest Proposition 25
# 	No v Yes: 2.0175749127496168e-68
#
# contest Proposition 25 AUDIT COMPLETE at risk limit 0.05. Attained risk 2.0175749127496168e-68
#
# p-values for assertions in contest AA-City of Orange
# 	No v Yes: 0.022639155501915677
#
# contest AA-City of Orange AUDIT COMPLETE at risk limit 0.05. Attained risk 0.022639155501915677
#
# p-values for assertions in contest Proposition 14
# 	No v Yes: 0.0
#
# contest Proposition 14 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest Proposition 15
# 	No v Yes: 0.0
#
# contest Proposition 15 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest Proposition 16
# 	No v Yes: 0.0
#
# contest Proposition 16 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest Proposition 17
# 	No v Yes: 2.71904188067891e-32
#
# contest Proposition 17 AUDIT COMPLETE at risk limit 0.05. Attained risk 2.71904188067891e-32
#
# p-values for assertions in contest Proposition 18
# 	No v Yes: 0.0
#
# contest Proposition 18 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest Z-City of Newport Beach
# 	Yes v No: 0.02425937009152801
#
# contest Z-City of Newport Beach AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02425937009152801
#
# p-values for assertions in contest CC-City of Tustin
# 	Yes v No: 0.017674822650337676
#
# contest CC-City of Tustin AUDIT COMPLETE at risk limit 0.05. Attained risk 0.017674822650337676
#
# p-values for assertions in contest S-City of Fullerton
# 	No v Yes: 0.024126779423573837
#
# contest S-City of Fullerton AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024126779423573837
#
# p-values for assertions in contest U-City of Fullerton
# 	No v Yes: 0.00554684271160442
#
# contest U-City of Fullerton AUDIT COMPLETE at risk limit 0.05. Attained risk 0.00554684271160442
#
# p-values for assertions in contest DD-City of Westminster
# 	Yes v No: 0.020561375754729667
#
# contest DD-City of Westminster AUDIT COMPLETE at risk limit 0.05. Attained risk 0.020561375754729667
#
# p-values for assertions in contest Y-City of Los Alamitos
# 	Yes v No: 0.024275561788746812
#
# contest Y-City of Los Alamitos AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024275561788746812
#
# p-values for assertions in contest Q-City of Costa Mesa
# 	Yes v No: 0.024486164667237888
#
# contest Q-City of Costa Mesa AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024486164667237888
#
# p-values for assertions in contest P-City of Cypress
# 	Yes v No: 0.024886650699632164
#
# contest P-City of Cypress AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024886650699632164
#
# p-values for assertions in contest BB-City of San Clemente
# 	Yes v No: 1.935527547088004e-08
#
# contest BB-City of San Clemente AUDIT COMPLETE at risk limit 0.05. Attained risk 1.935527547088004e-08
#
# p-values for assertions in contest W-City of La Habra
# 	Yes v No: 0.022512632001793875
#
# contest W-City of La Habra AUDIT COMPLETE at risk limit 0.05. Attained risk 0.022512632001793875
#
# p-values for assertions in contest X-City of La Habra
# 	Yes v No: 0.0034835643254246445
#
# contest X-City of La Habra AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0034835643254246445
#
# p-values for assertions in contest V-City of Laguna Woods
# 	Yes v No: 0.024877008039862317
#
# contest V-City of Laguna Woods AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024877008039862317
#
# p-values for assertions in contest ORANGE COUNTY WATER DISTRICT
# Director, Division 4
# 	TRI TA v TAI DO: 3.295101305515774e-94
# 	TRI TA v WRITE_IN: 1.1345878111382337e-123
# 	TRI TA v KRIS BEARD: 2.5296306991616322e-57
# 	TRI TA v SAMANTHA BAO ANH NGUYEN: 3.9644705562531903e-109
# 	TRI TA v JASMIN CARMADELLA: 4.573819929267508e-84
#
# contest ORANGE COUNTY WATER DISTRICT
# Director, Division 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 2.5296306991616322e-57
#
# p-values for assertions in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 3
# 	ROBERT R. "BOB" MCVICKER v KATHY-NGUYET PHAM: 3.016073837120617e-117
# 	ROBERT R. "BOB" MCVICKER v WRITE_IN: 9.528560919316836e-169
# 	ROBERT R. "BOB" MCVICKER v LINDA MOULTON-PATTERSON: 4.345216066376068e-119
# 	ROBERT R. "BOB" MCVICKER v TYLER DIEP: 1.8969561170818e-60
#
# contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.8969561170818e-60
#
# p-values for assertions in contest ORANGE COUNTY WATER DISTRICT
# Director, Division 6
# 	CATHY GREEN v WRITE_IN: 1.2251197336112288e-67
# 	CATHY GREEN v MICHAEL ELLIOTT: 8.392791301190064e-22
#
# contest ORANGE COUNTY WATER DISTRICT
# Director, Division 6 AUDIT COMPLETE at risk limit 0.05. Attained risk 8.392791301190064e-22
#
# p-values for assertions in contest CITY OF GARDEN GROVE
# Mayor
# 	STEVE JONES v PHAT BUI: 3.785299314897868e-17
# 	STEVE JONES v DUY NGUYEN: 8.862441939598457e-31
# 	STEVE JONES v WRITE_IN: 1.3343411146772562e-33
# 	STEVE JONES v DONALD TAYLOR: 8.016448558447948e-31
#
# contest CITY OF GARDEN GROVE
# Mayor AUDIT COMPLETE at risk limit 0.05. Attained risk 3.785299314897868e-17
#
# p-values for assertions in contest IRVINE RANCH WATER DISTRICT
# Director, Division 4
# 	KAREN MCLAUGHLIN v AARTI KAUSHAL: 0.0
# 	KAREN MCLAUGHLIN v WRITE_IN: 0.0
# 	KAREN MCLAUGHLIN v MARY AILEEN MATHEIS: 2.3080414023458026e-106
#
# contest IRVINE RANCH WATER DISTRICT
# Director, Division 4 AUDIT COMPLETE at risk limit 0.05. Attained risk
# Member, City Council AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02502578024903269
#
# p-values for assertions in contest EAST ORANGE COUNTY WATER DISTRICT
# Director
# 	DOUGLASS S. DAVERT v JULIO F. MORALES: 3.159511925397614e-08
# 	DOUGLASS S. DAVERT v NOBLE ALEJANDRO DRAKOLN: 7.613673957824003e-19
# 	DOUGLASS S. DAVERT v WRITE_IN: 8.775871609313993e-32
# 	JOHN L SEARS v JULIO F. MORALES: 3.420928886959461e-05
# 	JOHN L SEARS v NOBLE ALEJANDRO DRAKOLN: 1.3778872924793808e-15
# 	JOHN L SEARS v WRITE_IN: 3.124477824424532e-28
#
# contest EAST ORANGE COUNTY WATER DISTRICT
# Director AUDIT COMPLETE at risk limit 0.05. Attained risk 3.420928886959461e-05
#
# p-values for assertions in contest MESA WATER DISTRICT
# Director, Division 2
# 	JAMES R. FISLER v ADAM C. ERETH: 1.6064916896162686e-06
# 	JAMES R. FISLER v WRITE_IN: 5.51751544704324e-26
#
# contest MESA WATER DISTRICT
# Director, Division 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.6064916896162686e-06
#
# p-values for assertions in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 4
# 	KARL SECKEL v STACY LYNNE TAYLOR: 9.413135623149866e-15
# 	KARL SECKEL v WRITE_IN: 1.6832121512924345e-67
# 	KARL SECKEL v DANA M REED: 1.708073188322388e-65
# 	KARL SECKEL v ALLAN R. MANSOOR: 4.737982799673123e-32
# 	KARL SECKEL v CHRISTOPHER GANIERE: 2.511261638310185e-60
#
# contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 9.413135623149866e-15
#
# p-values for assertions in contest CITY OF HUNTINGTON BEACH
# City Treasurer
# 	ALISA BACKSTROM v WRITE_IN: 1.3509995489807427e-48
#
# contest CITY OF HUNTINGTON BEACH
# City Treasurer AUDIT COMPLETE at risk limit 0.05. Attained risk 1.3509995489807427e-48
#
# p-values for assertions in contest CITY OF HUNTINGTON BEACH
# City Clerk
# 	ROBIN ESTANISLAU v WRITE_IN: 5.501775283682122e-49
#
# contest CITY OF HUNTINGTON BEACH
# City Clerk AUDIT COMPLETE at risk limit 0.05. Attained risk 5.501775283682122e-49
#
# p-values for assertions in contest CITY OF WESTMINSTER
# Member, City Council, District 2
# 	CARLOS MANZO v WRITE_IN: 2.683666965311806e-08
# 	CARLOS MANZO v NAMQUAN NGUYEN: 0.024537700254687687
# 	CARLOS MANZO v TRUNG TA: 6.732314624578472e-05
#
# contest CITY OF WESTMINSTER
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024537700254687687
#
# p-values for assertions in contest CITY OF GARDEN GROVE
# Member, City Council, District 6
# 	KIM BERNICE NGUYEN v HUAN C. NGUYEN: 0.01698298625490684
# 	KIM BERNICE NGUYEN v WRITE_IN: 0.001617915526254528
#
# contest CITY OF GARDEN GROVE
# Member, City Council, District 6 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.01698298625490684
#
# p-values for assertions in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 7
# 	MEGAN YOO SCHNEIDER v DEBBIE NEEV: 2.6645536403802812e-62
# 	MEGAN YOO SCHNEIDER v WRITE_IN: 3.4044520896370985e-258
#
# contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 7 AUDIT COMPLETE at risk limit 0.05. Attained risk 2.6645536403802812e-62
#
# p-values for assertions in contest SANTA MARGARITA WATER DISTRICT
# Director
# 	CHARLES "CHUCK" GIBSON v WARREN MARTIN: 1.1261082716029128e-10
# 	CHARLES "CHUCK" GIBSON v WRITE_IN: 2.1569458236340964e-32
# 	BETTY H. OLSON v WARREN MARTIN: 5.333832669304025e-09
# 	BETTY H. OLSON v WRITE_IN: 2.211061522435196e-30
# 	FRANK URY v WARREN MARTIN: 0.0003313314519105472
# 	FRANK URY v WRITE_IN: 1.164763736465941e-24
#
# contest SANTA MARGARITA WATER DISTRICT
# Director AUDIT COMPLETE at risk limit 0.05. Attained risk 0.
UDIT COMPLETE at risk limit 0.05. Attained risk 0.0005614685374289447
#
# p-values for assertions in contest CITY OF SAN CLEMENTE
# Member, City Council, Short Term
# 	STEVEN KNOBLOCK v DONNA VIDRINE: 6.821147299142234e-07
# 	STEVEN KNOBLOCK v ZHEN WU: 1.445828042748643e-14
# 	STEVEN KNOBLOCK v JERRY QUINLAN: 4.292706325402873e-27
# 	STEVEN KNOBLOCK v WRITE_IN: 8.319439189917176e-30
# 	STEVEN KNOBLOCK v GEORGE T. GREGORY: 1.2258034161290415e-26
# 	STEVEN KNOBLOCK v TYLER BODEN: 8.939338424874478e-08
# 	STEVEN KNOBLOCK v LARON RUSH: 6.831635825328143e-27
# 	STEVEN KNOBLOCK v JIM DAHL: 0.006893017189288421
#
# contest CITY OF SAN CLEMENTE
# Member, City Council, Short Term AUDIT COMPLETE at risk limit 0.05. Attained risk 0.006893017189288421
#
# p-values for assertions in contest CITY OF SAN CLEMENTE
# City Clerk
# 	JOANNE BAADE v WRITE_IN: 8.55007265837428e-106
#
# contest CITY OF SAN CLEMENTE
# City Clerk AUDIT COMPLETE at risk limit 0.05. Attained risk 8.55007265837428e-106
#
# p-values for assertions in contest CITY OF SAN CLEMENTE
# City Treasurer
# 	MARK A. TAYLOR v WRITE_IN: 1.563837155443817e-109
#
# contest CITY OF SAN CLEMENTE
# City Treasurer AUDIT COMPLETE at risk limit 0.05. Attained risk 1.563837155443817e-109
#
# p-values for assertions in contest CITY OF ORANGE
# City Treasurer
# 	RICHARD A ROHM v WRITE_IN: 1.0234107175453708e-65
#
# contest CITY OF ORANGE
# City Treasurer AUDIT COMPLETE at risk limit 0.05. Attained risk 1.0234107175453708e-65
#
# p-values for assertions in contest PRESIDENT AND VICE PRESIDENT
# 	JOSEPH R. BIDEN
# KAMALA D. HARRIS v HOWIE HAWKINS
# ANGELA NICOLE WALKER: 0.0
# 	JOSEPH R. BIDEN
# KAMALA D. HARRIS v WRITE_IN: 0.0
# 	JOSEPH R. BIDEN
# KAMALA D. HARRIS v DONALD J. TRUMP
# MICHAEL R. PENCE: 0.0
# 	JOSEPH R. BIDEN
# KAMALA D. HARRIS v JO JORGENSEN
# JEREMY "SPIKE" COHEN: 0.0
# 	JOSEPH R. BIDEN
# KAMALA D. HARRIS v ROQUE "ROCKY" DE LA FUENTE GUERRA
# KANYE OMARI WEST: 0.0
# 	JOSEPH R. BIDEN
# KAMALA D. HARRIS v GLORIA LA RIVA
# SUNIL FREEMAN: 0.0
#
# contest PRESIDENT AND VICE PRESIDENT AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest UNITED STATES REPRESENTATIVE
# 45th District
# 	KATIE PORTER v GREG RATHS: 0.0
#
# contest UNITED STATES REPRESENTATIVE
# 45th District AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest STATE SENATOR
# 37th District
# 	DAVE MIN v JOHN M. W. MOORLACH: 4.433865560326767e-126
#
# contest STATE SENATOR
# 37th District AUDIT COMPLETE at risk limit 0.05. Attained risk 4.433865560326767e-126
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 68th District
# 	STEVEN "STEVE" CHOI v MELISSA FOX: 3.2424990482067527e-196
#
# contest MEMBER OF THE STATE ASSEMBLY
# 68th District AUDIT COMPLETE at risk limit 0.05. Attained risk 3.2424990482067527e-196
#
# p-values for assertions in contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2
# 	JOHN ORTEGA v TIGER KENNEDY COSMOS: 1.331528895705311e-12
# 	JOHN ORTEGA v WRITE_IN: 4.888357703328613e-84
#
# contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.331528895705311e-12
#
# p-values for assertions in contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3
# 	ANA PAGE v ALEXIA DELIGIANNI-BRYDGES: 1.626668327059639e-22
# 	ANA PAGE v WRITE_IN: 1.0828407069394793e-88
#
# contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.626668327059639e-22
#
# p-values for assertions in contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 6
# 	ANGIE SCHLUETER-RUMSEY v CARRIE LUNDELL: 3.081392126719823e-12
# 	ANGIE SCHLUETER-RUMSEY v WRITE_IN: 1.42224868144588e-68
# 	ANGIE SCHLUETER-RUMSEY v ALEX MUÑOZ: 1.2203184592785881e-55
# 	ANGIE SCHLUETER-RUMSEY v APRIL BRASWELL: 3.789714623015044e-57
#
# contest ORANGE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 6 AUDIT COMPLETE at risk limit 0.05. Attained risk 3.081392126719823e-12
#
# p-values for assertions in contest CITY OF ORANGE
# Mayor
# 	MARK A MURPHY v WRITE_IN: 1.0881168366139859e-44
# 	MARK A MURPHY v ADRIENNE GLADSON: 2.8923034722988246e-13
#
# contest CITY OF ORANGE
# Mayor AUDIT COMPLETE at risk limit 0.05. Attained risk 2.8923034722988246e-13
#
# p-values for assertions in contest CITY OF ORANGE
# City Clerk
# 	PAMELA COLEMAN v WRITE_IN: 5.110594722259212e-67
#
# contest CITY OF ORANGE
# City Clerk AUDIT COMPLETE at risk limit 0.05. Attained risk 5.110594722259212e-67
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 73rd District
# 	LAURIE DAVIES v SCOTT RHINEHART: 2.7141758207196213e-74
#
# contest MEMBER OF THE STATE ASSEMBLY
# 73rd District AUDIT COMPLETE at risk limit 0.05. Attained risk 2.7141758207196213e-74
#
# p-values for assertions in contest SADDLEBACK VALLEY UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2
# 	EDWARD WONG v TRICIA YEE: 0.024552295065620372
# 	EDWARD WONG v WRITE_IN: 3.605490063616418e-12
#
# contest SADDLEBACK VALLEY UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024552295065620372
#
# p-values for assertions in contest CITY OF LAGUNA HILLS
# Member, City Council
# 	JANINE HEFT v NICK WOOD: 6.842262852858103e-07
# 	JANINE HEFT v WRITE_IN: 1.3637247420354228e-09
# 	BILL HUNT v NICK WOOD: 2.4186330855558693e-06
# 	BILL HUNT v WRITE_IN: 5.443506512368136e-09
#
# contest CITY OF LAGUNA HILLS
# Member, City Council AUDIT COMPLETE at risk limit 0.05. Attained risk 2.4186330855558693e-06
#
# p-values for assertions in contest UNITED STATES REPRESENTATIVE
# 48th District
# 	MICHELLE STEEL v HARLEY ROUDA: 9.62541351614436e-13
#
# contest UNITED STATES REPRESENTATIVE
# 48th District AUDIT COMPLETE at risk limit 0.05. Attained risk 9.62541351614436e-13
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 74th District
# 	COTTIE PETRIE-NORRIS v DIANE DIXON: 6.080502069158156e-23
#
# contest MEMBER OF THE STATE ASSEMBLY
# 74th District AUDIT COMPLETE at risk limit 0.05. Attained risk 6.080502069158156e-23
#
# p-values for assertions in contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3
# 	CAROL CRANE v CHARLES KENT BOOKER: 1.1781112311347657e-05
# 	CAROL CRANE v WRITE_IN: 2.742437431891547e-12
#
# contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.1781112311347657e-05
#
# p-values for assertions in contest CITY OF NEWPORT BEACH
# Member, City Council, District 2
# 	BRAD AVERY v NANCY SCARBROUGH: 5.2265987739230044e-08
# 	BRAD AVERY v WRITE_IN: 4.9145487977502535e-25
#
# contest CITY OF NEWPORT BEACH
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 5.2265987739230044e-08
#
# p-values for assertions in contest CITY OF NEWPORT BEACH
# Member, City Council, District 5
# 	NOAH BLOM v JEFF HERDMAN: 7.55506501742389e-08
# 	NOAH BLOM v WRITE_IN: 6.198016482921716e-25
#
# contest CITY OF NEWPORT BEACH
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 7.55506501742389e-08
#
# p-values for assertions in contest CITY OF NEWPORT BEACH
# Member, City Council, District 7
# 	WILL O'NEILL v WRITE_IN: 1.033048090021834e-36
#
# contest CITY OF NEWPORT BEACH
# Member, City Council, District 7 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.033048090021834e-36
#
# p-values for assertions in contest UNITED STATES REPRESENTATIVE
# 39th District
# 	YOUNG KIM v GIL CISNEROS: 4.514003004397535e-58
#
# contest UNITED STATES REPRESENTATIVE
# 39th District AUDIT COMPLETE at risk limit 0.05. Attained risk 4.514003004397535e-58
#
# p-values for assertions in contest STATE SENATOR
# 29th District
# 	JOSH NEWMAN v LING LING CHANG: 1.6611445593311455e-44
#
# contest STATE SENATOR
# 29th District AUDIT COMPLETE at risk limit 0.05. Attained risk 1.6611445593311455e-44
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 55th District
# 	PHILLIP CHEN v ANDREW E. RODRIGUEZ: 7.366360783493038e-185
#
# contest MEMBER OF THE STATE ASSEMBLY
# 55th District AUDIT COMPLETE at risk limit 0.05. Attained risk 7.366360783493038e-185
#
# p-values for assertions in contest NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 4
# 	EVANGELINA REA ROSALES v MIGUEL ALVAREZ: 4.288476137386959e-17
# 	EVANGELINA REA ROSALES v WRITE_IN: 4.1261052047862976e-72
#
# contest NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 4.288476137386959e-17
#
# p-values for assertions in contest LA HABRA CITY SCHOOL DISTRICT
# Governing Board Member,
# Full Term
# 	SUSAN M. PRITCHARD v JOHN DOBSON: 0.01644072548943305
# 	SUSAN M. PRITCHARD v WRITE_IN: 1.7621492917692914e-07
# 	OFELIA CORONA HANSON v JOHN DOBSON: 0.020623839923306506
# 	OFELIA CORONA HANSON v WRITE_IN: 2.3142140795692003e-07
#
# contest LA HABRA CITY SCHOOL DISTRICT
# Governing Board Member,
# Full Term AUDIT COMPLETE at risk limit 0.05. Attained risk 0.020623839923306506
#
# p-values for assertions in contest CITY OF LA HABRA
# Member, City Council
# 	ROSE ESPINOZA v PETER CRUZ: 9.45490437880591e-05
# 	ROSE ESPINOZA v WRITE_IN: 8.472650864933356e-10
# 	ROSE ESPINOZA v MICHAEL NAVARRO: 4.173802209809175e-06
# 	TIM SHAW v PETER CRUZ: 0.0056397608790070405
# 	TIM SHAW v WRITE_IN: 1.0928754795007988e-07
# 	TIM SHAW v MICHAEL NAVARRO: 0.0003024373281733324
# 	STEVE SIMONIAN v PETER CRUZ: 0.00890335313402223
# 	STEVE SIMONIAN v WRITE_IN: 1.8738811800144643e-07
# 	STEVE SIMONIAN v MICHAEL NAVARRO: 0.00048755560530513265
#
# contest CITY OF LA HABRA
# Member, City Council AUDIT COMPLETE at risk limit 0.05. Attained risk 0.00890335313402223
#
# p-values for assertions in contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 1, Short Term
# 	AL NEDERHOOD v SCOTT HUPP: 0.0
# 	AL NEDERHOOD v WRITE_IN: 0.0
# 	AL NEDERHOOD v FRED R. SMITH: 0.0
#
# contest MUNICIPAL WATER DISTRICT OF ORANGE COUNTY
# Director, Division 1, Short Term AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest COSTA MESA SANITARY DISTRICT
# Director, Division 2
# 	BRETT ECKLES v JAMES FERRYMAN: 0.005709099723819749
# 	BRETT ECKLES v WRITE_IN: 3.247113637016685e-17
#
# contest COSTA MESA SANITARY DISTRICT
# Director, Division 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.005709099723819749
#
# p-values for assertions in contest UNITED STATES REPRESENTATIVE
# 46th District
# 	LOU CORREA v JAMES S. WATERS: 1.1216283926526417e-80
#
# contest UNITED STATES REPRESENTATIVE
# 46th District AUDIT COMPLETE at risk limit 0.05. Attained risk 1.1216283926526417e-80
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 69th District
# 	TOM DALY v JON PAUL WHITE: 1.5805120655737826e-46
#
# contest MEMBER OF THE STATE ASSEMBLY
# 69th District AUDIT COMPLETE at risk limit 0.05. Attained risk 1.5805120655737826e-46
#
# p-values for assertions in contest NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 5
# 	JACQUELINE RODARTE v DAVE GARCIA-GOMEZ: 1.437987928786248e-12
# 	JACQUELINE RODARTE v WRITE_IN: 9.931610283094777e-30
#
# contest NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.437987928786248e-12
#
# p-values for assertions in contest CITY OF ANAHEIM
# Member, City Council, District 4
# 	AVELINO VALENCIA v JEANINE A. ROBBINS: 0.011189770549958533
# 	AVELINO VALENCIA v WRITE_IN: 0.00028066694185349
# 	AVELINO VALENCIA v ANNEMARIE RANDLE-TREJO: 0.01367406096754134
# 	AVELINO VALENCIA v JULIE BRUNETTE: 0.0006299045422428564
#
# contest CITY OF ANAHEIM
# Member, City Council, District 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.01367406096754134
#
# p-values for assertions in contest SANTA ANA UNIFIED SCHOOL DISTRICT
# Governing Board Member
# 	CAROLYN TORRES v JUDITH CARRILLO: 2.869148134690828e-38
# 	CAROLYN TORRES v OSCAR REYES: 3.531382720081742e-43
# 	CAROLYN TORRES v WRITE_IN: 7.746006712318453e-83
# 	CAROLYN TORRES v CECILIA AGUINAGA: 4.621204534821126e-46
# 	RIGO RODRIGUEZ v JUDITH CARRILLO: 2.0407625921942275e-26
# 	RIGO RODRIGUEZ v OSCAR REYES: 3.8596603751796168e-31
# 	RIGO RODRIGUEZ v WRITE_IN: 3.499175149159898e-69
# 	RIGO RODRIGUEZ v CECILIA AGUINAGA: 6.520111685603248e-34
# 	ALFONSO ALVAREZ v JUDITH CARRILLO: 1.582399701230341e-11
# 	ALFONSO ALVAREZ v OSCAR REYES: 5.016066316132162e-16
# 	ALFONSO ALVAREZ v WRITE_IN: 3.876711432048762e-52
# 	ALFONSO ALVAREZ v CECILIA AGUINAGA: 1.1514568580780654e-18
#
# contest SANTA ANA UNIFIED SCHOOL DISTRICT
# Governing Board Member AUDIT COMPLETE at risk limit 0.05. Attained risk 1.582399701230341e-11
#
# p-values for assertions in contest County Supervisor, 1st District
# 	ANDREW DO v WRITE_IN: 3.7779086704496366e-111
# 	ANDREW DO v SERGIO CONTRERAS: 1.1173295726465988e-07
#
# contest County Supervisor, 1st District AUDIT COMPLETE at risk limit 0.05. Attained risk 1.1173295726465988e-07
#
# p-values for assertions in contest UNITED STATES REPRESENTATIVE
# 47th District
# 	ALAN LOWENTHAL v JOHN BRISCOE: 7.692230667517962e-13
#
# contest UNITED STATES REPRESENTATIVE
# 47th District AUDIT COMPLETE at risk limit 0.05. Attained risk 7.692230667517962e-13
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 65th District
# 	SHARON QUIRK-SILVA v CYNTHIA THACKER: 1.2071547218686984e-69
#
# contest MEMBER OF THE STATE ASSEMBLY
# 65th District AUDIT COMPLETE at risk limit 0.05. Attained risk 1.2071547218686984e-69
#
# p-values for assertions in contest CITY OF STANTON
# Member, City Council, District 4
# 	CAROL WARREN v JOSH ESTRADA: 0.0007593212263584951
# 	CAROL WARREN v WRITE_IN: 1.272067753811136e-05
# 	CAROL WARREN v JEFF JONES: 0.02301154751025938
#
# contest CITY OF STANTON
# Member, City Council, District 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02301154751025938
#
# p-values for assertions in contest MEMBER OF THE STATE ASSEMBLY
# 72nd District
# 	JANET NGUYEN v DIEDRE NGUYEN: 3.9790036108839156e-32
#
# contest MEMBER OF THE STATE ASSEMBLY
# 72nd District AUDIT COMPLETE at risk limit 0.05. Attained risk 3.9790036108839156e-32
#
# p-values for assertions in contest RANCHO SANTIAGO COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 5
# 	DAVID CROCKETT v BRETT ELLIOTT FRANKLIN: 2.2571950170332156e-05
# 	DAVID CROCKETT v WRITE_IN: 7.893109212870252e-14
# 	DAVID CROCKETT v SAMUEL ULLOA: 1.6098345038384851e-09
#
# contest RANCHO SANTIAGO COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 2.2571950170332156e-05
#
# p-values for assertions in contest CITY OF SANTA ANA
# Member, City Council, Ward 1
# 	THAI VIET PHAN v CYNTHIA CONTRERAS: 0.0008663665621097803
# 	THAI VIET PHAN v ANTONIO "TONY" ADAME: 0.024253757443617033
# 	THAI VIET PHAN v WRITE_IN: 8.703601330399838e-07
# 	THAI VIET PHAN v THOMAS ANTHONY GORDON: 7.234684724713847e-05
#
# contest CITY OF SANTA ANA
# Member, City Council, Ward 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024253757443617033
#
# p-values for assertions in contest CITY OF ANAHEIM
# Member, City Council, District 5
# 	STEVE FAESSEL v WRITE_IN: 1.9342296610373126e-16
# 	STEVE FAESSEL v KENNETH BATISTE: 4.657821638684549e-11
# 	STEVE FAESSEL v SABRINA "SAV" QUEZADA: 6.563315071224789e-07
#
# contest CITY OF ANAHEIM
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 6.563315071224789e-07
#
# p-values for assertions in contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 1
# 	CAROLYN INMON v HELEN LOCKE: 0.0
# 	CAROLYN INMON v AARTI KAUSHAL: 0.0
# 	CAROLYN INMON v WRITE_IN: 0.0
# 	CAROLYN INMON v MATT WAID: 0.0
#
# contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 6
# 	JAMES R. WRIGHT v RYAN DACK: 0.0
# 	JAMES R. WRIGHT v WRITE_IN: 0.0
#
# contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 6 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7
# 	TIMOTHY "TIM" JEMAL v WRITE_IN: 0.0
# 	TIMOTHY "TIM" JEMAL v MO ENTEZAMPOUR: 0.0
# 	TIMOTHY "TIM" JEMAL v SEAN GAWNE: 0.0
#
# contest SOUTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest CAPISTRANO UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5
# 	KRISTA CASTELLANOS v PAUL HEBBARD: 0.0005460726099551302
# 	KRISTA CASTELLANOS v WRITE_IN: 7.932382744943547e-08
# 	KRISTA CASTELLANOS v JASMINE FUNES: 1.9325761433520892e-05
#
# contest CAPISTRANO UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0005460726099551302
#
# p-values for assertions in contest CITY OF ALISO VIEJO
# Member, City Council
# 	MIKE MUNZING v WRITE_IN: 1.0199776556807676e-07
# 	MIKE MUNZING v DAVID ZERO: 5.464635173371189e-05
# 	MIKE MUNZING v GREG J. WILLIAMS: 1.5717981807975827e-05
# 	MIKE MUNZING v MAX DUNCAN: 0.000535438620757691
# 	MIKE MUNZING v MICHAEL W. BROWN: 3.02702775933698e-05
NIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2
# 	JAMES H. LAIRD v WRITE_IN: 1.8810548139083788e-172
# 	JAMES H. LAIRD v SUSAN M. STOCKS: 1.2210306871309047e-67
#
# contest TUSTIN UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 1.2210306871309047e-67
#
# p-values for assertions in contest CITY OF MISSION VIEJO
# Member, City Council,
# Two-Year Term
# 	PATRICIA "TRISH" KELLEY v CATHY SCHLICHT: 2.310192476457251e-06
# 	PATRICIA "TRISH" KELLEY v STEVE SIPE: 2.3256233776579134e-08
# 	PATRICIA "TRISH" KELLEY v RYAN TWOREK: 2.4374530237152245e-08
# 	PATRICIA "TRISH" KELLEY v WRITE_IN: 5.123020586059895e-10
# 	PATRICIA "TRISH" KELLEY v JESSICA GILBERT: 7.89892255703908e-08
# 	PATRICIA "TRISH" KELLEY v MICHAEL MCCONNELL: 1.5856536228492764e-08
# 	PATRICIA "TRISH" KELLEY v PAULINE HALE: 8.619612300759902e-07
# 	BRIAN GOODELL v CATHY SCHLICHT: 5.452057577780478e-06
# 	BRIAN GOODELL v STEVE SIPE: 5.748940038229996e-08
# 	BRIAN GOODELL v RYAN TWOREK: 6.022455842455203e-08
# 	BRIAN GOODELL v WRITE_IN: 1.3185600917642838e-09
# 	BRIAN GOODELL v JESSICA GILBERT: 1.928230030746528e-07
# 	BRIAN GOODELL v MICHAEL MCCONNELL: 3.93533567893864e-08
# 	BRIAN GOODELL v PAULINE HALE: 2.054133671760761e-06
#
# contest CITY OF MISSION VIEJO
# Member, City Council,
# Two-Year Term AUDIT COMPLETE at risk limit 0.05. Attained risk 5.452057577780478e-06
#
# p-values for assertions in contest UNITED STATES REPRESENTATIVE
# 49th District
# 	BRIAN MARYOTT v MIKE LEVIN: 1.8977223854548082e-41
#
# contest UNITED STATES REPRESENTATIVE
# 49th District AUDIT COMPLETE at risk limit 0.05. Attained risk 1.8977223854548082e-41
#
# p-values for assertions in contest CAPISTRANO UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2
# 	PAMELA BRAUNSTEIN v JIM REARDON: 0.011406651987154317
# 	PAMELA BRAUNSTEIN v WRITE_IN: 2.364272062864443e-10
#
# contest CAPISTRANO UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.011406651987154317
#
# p-values for assertions in contest RANCHO SANTIAGO COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7
# 	TINA ARIAS MILLER v WRITE_IN: 3.3346262427734806e-26
# 	TINA ARIAS MILLER v LORETTA SANCHEZ: 0.00016912515732950056
#
# contest RANCHO SANTIAGO COMMUNITY COLLEGE DISTRICT
# Governing Board Member,
# Trustee Area 7 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.00016912515732950056
#
# p-values for assertions in contest CITY OF ORANGE
# Member, City Council, District 1
# 	ARIANNA BARRIOS v CHRISTIAN L. VAUGHAN: 0.0014094581704708741
# 	ARIANNA BARRIOS v EUGENE W. FIELDS: 0.0031735196165803953
# 	ARIANNA BARRIOS v WRITE_IN: 2.1420758514484182e-05
# 	ARIANNA BARRIOS v DAVID VAZQUEZ: 0.024821877843918733
#
# contest CITY OF ORANGE
# Member, City Council, District 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.
UNTINGTON BEACH UNION HIGH SCHOOL DISTRICT
# Governing Board Member AUDIT COMPLETE at risk limit 0.05. Attained risk 6.742398582369115e-20
#
# p-values for assertions in contest RANCHO SANTA MARGARITA
# Member, City Council
# 	TONY BEALL v WRITE_IN: 9.981097493623862e-09
# 	TONY BEALL v GLENN ACOSTA: 0.00016004357920230272
# 	TONY BEALL v CHRIS K. MCLAUGHLIN: 3.005017220553897e-07
# 	TONY BEALL v WENDY BRAUN: 2.9367228228613263e-07
# 	TONY BEALL v ANDREA MACHUCA: 1.156425786446878e-07
# 	TONY BEALL v BETH SCHWARTZ: 3.987291053172249e-05
# 	TONY BEALL v JULIA BENDIS: 4.115917311738498e-07
# 	TONY BEALL v JOHN CHRISTOPOULOS: 5.500688233372681e-06
# 	CAROL GAMBLE v WRITE_IN: 2.9204584214315833e-06
# 	CAROL GAMBLE v GLENN ACOSTA: 0.024267055709804277
# 	CAROL GAMBLE v CHRIS K. MCLAUGHLIN: 6.915821841429066e-05
# 	CAROL GAMBLE v WENDY BRAUN: 6.769387823376607e-05
# 	CAROL GAMBLE v ANDREA MACHUCA: 2.8439664306163365e-05
# 	CAROL GAMBLE v BETH SCHWARTZ: 0.0066126882007530065
# 	CAROL GAMBLE v JULIA BENDIS: 9.269290545414741e-05
# 	CAROL GAMBLE v JOHN CHRISTOPOULOS: 0.0010393329568771207
#
# contest RANCHO SANTA MARGARITA
# Member, City Council AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024267055709804277
#
# p-values for assertions in contest SOUTH COAST WATER DISTRICT
# Director
# 	RICK ERKENEFF v WAYNE RAYFIELD: 6.049716285164081e-16
# ...
# 	NATHAN SEARLES v MICHAEL MAYNARD: 0.02447611375565751
#
# contest ROSSMOOR COMMUNITY SERVICES DISTRICT
# Director, Full Term AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02447611375565751
#
# p-values for assertions in contest CITY OF GARDEN GROVE
# Member, City Council, District 2
# 	JOHN R. O'NEILL v JULIE DIEP: 0.02458659408580705
# 	JOHN R. O'NEILL v WRITE_IN: 2.708032432329845e-14
#
# contest CITY OF GARDEN GROVE
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02458659408580705
#
# p-values for assertions in contest CITY OF FULLERTON
# Member, City Council, District 4
# 	BRUCE WHITAKER v AARUNI THAKUR: 0.024735965801176693
# 	BRUCE WHITAKER v WRITE_IN: 1.1353873947461475e-36
#
# contest CITY OF FULLERTON
# Member, City Council, District 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.024735965801176693
#
# p-values for assertions in contest FOUNTAIN VALLEY SCHOOL DISTRICT
# Governing Board Member
# 	STEVE SCHULTZ v WRITE_IN: 2.9498224572776797e-34
# 	STEVE SCHULTZ v TOM NGUYEN: 1.4803984620791666e-18
# 	STEVE SCHULTZ v IAN COLLINS: 3.643687756164252e-15
# 	JEANNE GALINDO v WRITE_IN: 8.827325049775491e-25
# 	JEANNE GALINDO v TOM NGUYEN: 3.3310711391998183e-10
# 	JEANNE GALINDO v IAN COLLINS: 4.880685286677564e-07
#
# contest FOUNTAIN VALLEY SCHOOL DISTRICT
# Governing Board Member AUDIT COMPLETE at risk limit 0.05. Attained risk 4.880685286677564e-07
#
# p-values for assertions in contest CITY OF FOUNTAIN VALLEY
# Member, City Council
# 	GLENN GRANDIS v JIM CUNNEEN: 5.620540813723949e-09
# 	GLENN GRANDIS v WRITE_IN: 6.300421807710184e-26
# 	GLENN GRANDIS v CHERYL BROTHERS: 4.000965390515588e-05
# 	GLENN GRANDIS v MARY PHAM: 6.710686061946345e-19
# 	GLENN GRANDIS v TOM NGUYEN: 5.3426874494863016e-17
# 	GLENN GRANDIS v MAI KHANH TRAN: 1.1676321789016679e-05
# 	TED BUI v JIM CUNNEEN: 4.1768287492149325e-06
# 	TED BUI v WRITE_IN: 1.0556298696580892e-22
# 	TED BUI v CHERYL BROTHERS: 0.025031556704488058
# 	TED BUI v MARY PHAM: 7.935931394396627e-16
# 	TED BUI v TOM NGUYEN: 5.766084167146205e-14
# 	TED BUI v MAI KHANH TRAN: 0.007479805313897596
#
# contest CITY OF FOUNTAIN VALLEY
# Member, City Council AUDIT COMPLETE at risk limit 0.05. Attained risk 0.025031556704488058
#
# p-values for assertions in contest CITY OF COSTA MESA
# Member, City Council, District 2
# 	LOREN GAMEROS v BEN CHAPMAN: 0.0021961128392884786
# 	LOREN GAMEROS v WRITE_IN: 4.407669651534971e-08
# 	LOREN GAMEROS v GARY PARKIN: 6.81649980673232e-05
#
# contest CITY OF COSTA MESA
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0021961128392884786
#
# p-values for assertions in contest IRVINE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5
# 	PAUL BOKOTA v WRITE_IN: 0.0
# 	PAUL BOKOTA v DEMETRA ARVANITIDIS: 4.873402037869849e-186
#
# contest IRVINE UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 4.873402037869849e-186
#
# p-values for assertions in contest PLACENTIA-YORBA LINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2
# 	MARILYN ANDERSON v LASHÉ RODRIGUEZ: 0.01345807678715751
# 	MARILYN ANDERSON v JOSHUA CORREA: 1.2773395775178192e-05
# 	MARILYN ANDERSON v WRITE_IN: 1.166090221932664e-19
#
# contest PLACENTIA-YORBA LINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.01345807678715751
#
# p-values for assertions in contest CITY OF ORANGE
# Member, City Council, District 5
# 	ANA GUTIERREZ v RICK LEDESMA: 0.02465877698529514
# 	ANA GUTIERREZ v WRITE_IN: 3.6297796749736304e-17
#
# contest CITY OF ORANGE
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02465877698529514
#
# p-values for assertions in contest CITY OF ANAHEIM
# Member, City Council, District 1
# 	JOSE DIAZ v DENISE BARNES: 0.02464300046848298
# 	JOSE DIAZ v RYAN BALIUS: 1.6842105905311385e-09
# 	JOSE DIAZ v WRITE_IN: 7.944948610809236e-18
#
# contest CITY OF ANAHEIM
# Member, City Council, District 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02464300046848298
#
# p-values for assertions in contest WESTMINSTER SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1
# 	DAVID JOHNSON v WRITE_IN: 2.212862148185499e-07
# 	DAVID JOHNSON v ANGEL RAMIREZ: 0.001761582863955877
#
# contest WESTMINSTER SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.001761582863955877
#
# p-values for assertions in contest BUENA PARK LIBRARY DISTRICT
# Trustee
# 	PATRICIA GANER v DENNIS LEE SALTS: 1.9645950767957798e-32
# 	PATRICIA GANER v WRITE_IN: 4.7112046630058446e-63
# 	IRENE CASTANEDA v DENNIS LEE SALTS: 6.563997717763293e-10
# 	IRENE CASTANEDA v WRITE_IN: 1.6288612659349167e-36
# 	L CAROLE JENSEN v DENNIS LEE SALTS: 0.025112199214440918
# 	L CAROLE JENSEN v WRITE_IN: 1.035278010566788e-27
#
# contest BUENA PARK LIBRARY DISTRICT
# Trustee AUDIT COMPLETE at risk limit 0.05. Attained risk 0.025112199214440918
#
# p-values for assertions in contest CITY OF LOS ALAMITOS
# Member, City Council, District 1
# 	TANYA DOBY v WRITE_IN: 3.49151196549765e-66
# 	TANYA DOBY v DEAN GROSE: 0.019750716372372575
#
# contest CITY OF LOS ALAMITOS
# Member, City Council, District 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.019750716372372575
#
# p-values for assertions in contest CITY OF LAGUNA WOODS
# Member, City Council
# 	NOEL HATCH v JUDITH P. TROUTMAN: 0.00571056038825392
# 	NOEL HATCH v KATHRYN ROBBINS: 0.005343148566954258
# 	NOEL HATCH v WRITE_IN: 3.20348480775825e-07
# 	SHARI L HORNE v JUDITH P. TROUTMAN: 0.015003287198415687
# 	SHARI L HORNE v KATHRYN ROBBINS: 0.014053426698590958
# 	SHARI L HORNE v WRITE_IN: 1.0034585623596697e-06
# 	CYNTHIA CONNERS v JUDITH P. TROUTMAN: 0.0198279966322218
# 	CYNTHIA CONNERS v KATHRYN ROBBINS: 0.018578512710539084
# 	CYNTHIA CONNERS v WRITE_IN: 1.3943060537574298e-06
#
# contest CITY OF LAGUNA WOODS
# Member, City Council AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0198279966322218
#
# p-values for assertions in contest CITY OF BUENA PARK
# Member, City Council, District 4
# 	ARTHUR C. BROWN v DONNA VARONA SIPL: 0.0004981711540759479
# 	ARTHUR C. BROWN v WRITE_IN: 2.878809970573273e-12
#
# contest CITY OF BUENA PARK
# Member, City Council, District 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0004981711540759479
#
# p-values for assertions in contest CITY OF BUENA PARK
# Member, City Council, District 3
# 	SUSAN SONNE v PAUL D. GONZALES: 2.930451686749856e-08
# 	SUSAN SONNE v SHARON SMITH: 3.322420376796398e-05
# 	SUSAN SONNE v WRITE_IN: 5.520153237552624e-13
#
# contest CITY OF BUENA PARK
# Member, City Council, District 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 3.322420376796398e-05
#
# p-values for assertions in contest CITY OF PLACENTIA
# Member, City Council, District 3
# 	JEREMY B. YAMAGUCHI v WRITE_IN: 0.00017300557066758345
#
# contest CITY OF PLACENTIA
# Member, City Council, District 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.00017300557066758345
#
# p-values for assertions in contest CITY OF PLACENTIA
# City Clerk, Short Term
# 	ROBERT S. "BOB" MCKINNELL v WRITE_IN: 3.1481880553026955e-54
#
# contest CITY OF PLACENTIA
# City Clerk, Short Term AUDIT COMPLETE at risk limit 0.05. Attained risk 3.1481880553026955e-54
#
# p-values for assertions in contest CITY OF PLACENTIA
# City Treasurer
# 	KEVIN A. LARSON v WRITE_IN: 3.228902035906584e-53
#
# contest CITY OF PLACENTIA
# City Treasurer AUDIT COMPLETE at risk limit 0.05. Attained risk 3.228902035906584e-53
#
# p-values for assertions in contest CITY OF ORANGE
# Member, City Council, District 3
# 	MIKE ALVAREZ v JOHN R RUSSO: 0.023422900824315276
# 	MIKE ALVAREZ v WRITE_IN: 0.0002185995016867908
# 	MIKE ALVAREZ v DANETT ABBOTT-WICKER: 0.011161425924756795
#
# contest CITY OF ORANGE
# Member, City Council, District 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.023422900824315276
#
# p-values for assertions in contest LOS ALAMITOS UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5
# 	MEG CUTULI v WRITE_IN: 3.611272586719067e-05
# 	MEG CUTULI v MATT FILLER: 0.023546719131385358
#
# contest LOS ALAMITOS UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.023546719131385358
#
# p-values for assertions in contest CITY OF SEAL BEACH
# Member, City Council, District 2
# 	THOMAS MOORE v WRITE_IN: 1.0041971410213839e-05
# 	THOMAS MOORE v CAROLE S. DAMOCI: 0.0028664576119616742
#
# contest CITY OF SEAL BEACH
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0028664576119616742
#
# p-values for assertions in contest CITY OF SEAL BEACH
# Member, City Council, District 4
# 	SCHELLY SUSTARSIC v WRITE_IN: 0.01604129583203118
#
# contest CITY OF SEAL BEACH
# Member, City Council, District 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.01604129583203118
#
# p-values for assertions in contest BREA OLINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5
# 	LAUREN BARNES v WRITE_IN: 0.0
# 	LAUREN BARNES v GAIL LYONS: 0.0
#
# contest BREA OLINDA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0
#
# p-values for assertions in contest LOS ALAMITOS UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2
# 	CHRIS FOREHAN v JODY L. ROUBANIS: 6.499905693574778e-15
# 	CHRIS FOREHAN v WRITE_IN: 7.32154475924166e-26
# 	CHRIS FOREHAN v PAURVI TRIVEDI: 0.001498244659036018
#
# contest LOS ALAMITOS UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.001498244659036018
#
# p-values for assertions in contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 6
# 	KRISTA WEIGAND v AMY PETERS: 0.01560367413781199
# 	KRISTA WEIGAND v WRITE_IN: 8.618068366303693e-09
# 	KRISTA WEIGAND v XENO RALF MULLER II: 1.7381206191549672e-07
# 	KRISTA WEIGAND v ALEXIS ZAVOURIS: 4.098461945483295e-08
#
# contest NEWPORT-MESA UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 6 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.01560367413781199
#
# p-values for assertions in contest TUSTIN UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1
# 	ALLYSON M. DAMIKOLAS v WRITE_IN: 1.2699769111649482e-16
# 	ALLYSON M. DAMIKOLAS v KIRK O. HAHN: 1.1758677187334257e-12
# 	ALLYSON M. DAMIKOLAS v TAMMIE K. BULLARD: 0.0015521931802782913
#
# contest TUSTIN UNIFIED SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0015521931802782913
#
# p-values for assertions in contest ANAHEIM ELEMENTARY SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3
# 	JOSE PAOLO MAGCALAS v LUCILLE KRING: 0.020232422501863113
# 	JOSE PAOLO MAGCALAS v WRITE_IN: 6.216577084192734e-05
#
# contest ANAHEIM ELEMENTARY SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.020232422501863113
#
# p-values for assertions in contest CITY OF DANA POINT
# Member, City Council, District 5
# 	MICHAEL VILLAR v WRITE_IN: 7.007604507767981e-37
# 	MICHAEL VILLAR v BENJAMIN TYLER BEBEE: 7.560807466797426e-28
#
# contest CITY OF DANA POINT
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 7.560807466797426e-28
#
# p-values for assertions in contest CITY OF COSTA MESA
# Member, City Council, District 6
# 	JEFFREY HARLAN v HENGAMEH ABRAHAM: 0.001015607708428467
# 	JEFFREY HARLAN v JEFF PETTIS: 0.0012794738602724138
# 	JEFFREY HARLAN v LEE RAMOS: 0.0001943813376298756
# 	JEFFREY HARLAN v WRITE_IN: 4.8446620960429294e-06
#
# contest CITY OF COSTA MESA
# Member, City Council, District 6 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0012794738602724138
#
# p-values for assertions in contest BUENA PARK SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 4
# 	IRENE CASTANEDA v L CAROLE JENSEN: 0.00416818971643125
# 	IRENE CASTANEDA v WRITE_IN: 7.64883620031314e-05
#
# contest BUENA PARK SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 4 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.00416818971643125
#
# p-values for assertions in contest CITY OF PLACENTIA
# Member, City Council, District 5
# 	WARD L. SMITH v HILAIRE FUJI SHIOURA: 0.0005735190834876818
# 	WARD L. SMITH v WRITE_IN: 2.4518510232519263e-07
#
# contest CITY OF PLACENTIA
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.0005735190834876818
#
# p-values for assertions in contest CITY OF LOS ALAMITOS
# Member, City Council, District 2
# 	RON BATES v KATE HALLMAN: 0.012753876457016703
# 	RON BATES v WRITE_IN: 9.803273820052173e-05
#
# contest CITY OF LOS ALAMITOS
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.012753876457016703
#
# p-values for assertions in contest CITY OF LAKE FOREST
# Member, City Council, District 5
# 	ROBERT PEQUEÑO v JEANNETTE J. NADAL: 0.009417626394531479
# 	ROBERT PEQUEÑO v FRANK WAGONER: 0.0022576563945215433
# 	ROBERT PEQUEÑO v WRITE_IN: 0.000783040136550258
# 	ROBERT PEQUEÑO v LARISSA CLARK: 0.0049491145131648874
# 	ROBERT PEQUEÑO v SHANE JONES: 0.0015085575652464278
#
# contest CITY OF LAKE FOREST
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.009417626394531479
#
# p-values for assertions in contest CITY OF SAN JUAN CAPISTRANO
# Member, City Council, District 5
# 	HOWARD HART v JOHN ALPAY: 0.019734753580869884
# 	HOWARD HART v WRITE_IN: 0.00015848772593197348
#
# contest CITY OF SAN JUAN CAPISTRANO
# Member, City Council, District 5 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.019734753580869884
#
# p-values for assertions in contest CITY OF LOS ALAMITOS
# Member, City Council, District 3
# 	JORDAN B. NEFULDA v WRITE_IN: 0.018674045020699827
#
# contest CITY OF LOS ALAMITOS
# Member, City Council, District 3 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.018674045020699827
#
# p-values for assertions in contest CITY OF PLACENTIA
# Member, City Council, District 1
# 	RHONDA SHADER v DEVON GRAY: 0.02411674889478387
# 	RHONDA SHADER v WRITE_IN: 1.1811646315593715e-15
#
# contest CITY OF PLACENTIA
# Member, City Council, District 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02411674889478387
#
# p-values for assertions in contest HUNTINGTON BEACH CITY SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1
# 	BRIDGET KAUB v WRITE_IN: 1.8878268288532464e-10
# 	BRIDGET KAUB v ROGER S. NOOR: 7.412473228713283e-07
#
# contest HUNTINGTON BEACH CITY SCHOOL DISTRICT
# Governing Board Member,
# Trustee Area 1 AUDIT COMPLETE at risk limit 0.05. Attained risk 7.412473228713283e-07
#
# p-values for assertions in contest SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT
# Director, Full Term
# 	JAMES GUZIAK v BHAVIN PATEL: 1.1628612261943323e-06
# 	JAMES GUZIAK v WRITE_IN: 5.689353522081844e-27
# 	CRAIG S. SCHILL v BHAVIN PATEL: 0.019906606828242884
# 	CRAIG S. SCHILL v WRITE_IN: 1.247530056610572e-21
#
# contest SANTIAGO GEOLOGIC HAZARD ABATEMENT DISTRICT
# Director, Full Term AUDIT COMPLETE at risk limit 0.05. Attained risk 0.019906606828242884
#
# p-values for assertions in contest SILVERADO-MODJESKA RECREATION AND PARK DISTRICT
# Director
# 	MICHELE GRACE AGOPIAN v WRITE_IN: 2.6321997065875854e-15
# 	MICHELE GRACE AGOPIAN v CELESTE GOFF VEERKAMP: 0.005545378498623357
# 	JULIE A. MORRIS v WRITE_IN: 1.5855747954101558e-14
# 	JULIE A. MORRIS v CELESTE GOFF VEERKAMP: 0.02298958682708406
#
# contest SILVERADO-MODJESKA RECREATION AND PARK DISTRICT
# Director AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02298958682708406
#
# p-values for assertions in contest CITY OF STANTON
# Member, City Council, District 2
# 	HONG ALYCE VAN v DEWAYNE ALLEN NORMAND: 0.023851626281433853
# 	HONG ALYCE VAN v WRITE_IN: 9.843498678663033e-28
#
# contest CITY OF STANTON
# Member, City Council, District 2 AUDIT COMPLETE at risk limit 0.05. Attained risk 0.023851626281433853
#
# p-values for assertions in contest CAPISTRANO BAY COMMUNITY SERVICES DISTRICT
# Director
# 	BRAD L. JENKINS v YURI CRAMER: 0.0006832087939307188
# 	BRAD L. JENKINS v WRITE_IN: 3.2888666705009015e-07
# 	WILLIAM WIERSIG v YURI CRAMER: 0.02034488307640936
# 	WILLIAM WIERSIG v WRITE_IN: 2.41206428315801e-05
#
# contest CAPISTRANO BAY COMMUNITY SERVICES DISTRICT
# Director AUDIT COMPLETE at risk limit 0.05. Attained risk 0.02034488307640936
# CPU times: user 37.5 s, sys: 38.8 ms, total: 37.5 s
# Wall time: 37.5 s

# %%
# Log the status of the audit 
audit.write_audit_parameters(contests)

# %% [markdown]
# # How many more cards should be audited?
#
# Estimate how many more cards will need to be audited to confirm any remaining contests. The enlarged sample size is based on:
#
# * cards already sampled
# * the assumption that we will continue to see errors at the same rate observed in the sample

# %%
# %%time
sample_size = audit.find_sample_size(contests, cvr_list, mvr_sample)
print(f'{sample_size=}\n{[(i, c.sample_size) for i, c in contests.items()]}')
# Out:
# sample_size=23990
# [('Proposition 19', 0), ('Proposition 20', 0), ('Proposition 21', 0), ('Proposition 22', 0), ('Proposition 23', 0), ('Proposition 24', 0), ('Proposition 25', 0), ('AA-City of Orange', 0), ('Proposition 14', 0), ('Proposition 15', 0), ('Proposition 16', 0), ('Proposition 17', 0), ('Proposition 18', 0), ('Z-City of Newport Beach', 0), ('CC-City of Tustin', 0), ('S-City of Fullerton', 0), ('U-City of Fullerton', 0), ('DD-City of Westminster', 0), ('Y-City of Los Alamitos', 0), ('Q-City of Costa Mesa', 0), ('P-City of Cypress', 0), ('BB-City of San Clemente', 0), ('W-City of La Habra', 0), ('X-City of La Habra', 0), ('V-City of Laguna Woods', 0), ('ORANGE COUNTY WATER DISTRICT\nDirector, Division 4', 0), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 3', 0), ('ORANGE COUNTY WATER DISTRICT\nDirector, Division 6', 0), ('CITY OF GARDEN GROVE\nMayor', 0), ('IRVINE RANCH WATER DISTRICT\nDirector, Division 4', 0), ('CITY OF WESTMINSTER\nMember, City Council, District 3', 0), ('MIDWAY CITY SANITARY DISTRICT\nDirector', 0), ('IRVINE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3', 0), ('CITY OF IRVINE\nMayor', 0), ('CITY OF IRVINE\nMember, City Council', 0), ('CITY OF TUSTIN\nMember, City Council', 0), ('EAST ORANGE COUNTY WATER DISTRICT\nDirector', 0), ('MESA WATER DISTRICT\nDirector, Division 2', 0), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 4', 0), ('CITY OF HUNTINGTON BEACH\nCity Treasurer', 0), ('CITY OF HUNTINGTON BEACH\nCity Clerk', 0), ('CITY OF WESTMINSTER\nMember, City Council, District 2', 0), ('CITY OF GARDEN GROVE\nMember, City Council, District 6', 0), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 7', 0), ('SANTA MARGARITA WATER DISTRICT\nDirector', 0), ('CITY OF HUNTINGTON BEACH\nMember, City Council', 0), ('CITY OF SANTA ANA\nMayor', 0), ('CITY OF SANTA ANA\nMember, City Council, Ward 3', 0), ('CITY OF SAN CLEMENTE\nMember, City Council, Full Term', 0), ('CITY OF SAN CLEMENTE\nMember, City Council, Short Term', 0), ('CITY OF SAN CLEMENTE\nCity Clerk', 0), ('CITY OF SAN CLEMENTE\nCity Treasurer', 0), ('CITY OF ORANGE\nCity Treasurer', 0), ('PRESIDENT AND VICE PRESIDENT', 0), ('UNITED STATES REPRESENTATIVE\n45th District', 0), ('STATE SENATOR\n37th District', 0), ('MEMBER OF THE STATE ASSEMBLY\n68th District', 0), ('ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 2', 0), ('ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3', 0), ('ORANGE UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 6', 0), ('CITY OF ORANGE\nMayor', 0), ('CITY OF ORANGE\nCity Clerk', 0), ('MEMBER OF THE STATE ASSEMBLY\n73rd District', 0), ('SADDLEBACK VALLEY UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 2', 0), ('CITY OF LAGUNA HILLS\nMember, City Council', 0), ('UNITED STATES REPRESENTATIVE\n48th District', 0), ('MEMBER OF THE STATE ASSEMBLY\n74th District', 0), ('NEWPORT-MESA UNIFIED SCHOOL DISTRICT\nGoverning Board Member,\nTrustee Area 3', 0), ('CITY OF NEWPORT BEACH\nMember, City Council, District 2', 0), ('CITY OF NEWPORT BEACH\nMember, City Council, District 5', 0), ('CITY OF NEWPORT BEACH\nMember, City Council, District 7', 0), ('UNITED STATES REPRESENTATIVE\n39th District', 0), ('STATE SENATOR\n29th District', 0), ('MEMBER OF THE STATE ASSEMBLY\n55th District', 0), ('NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT\nGoverning Board Member,\nTrustee Area 4', 0), ('LA HABRA CITY SCHOOL DISTRICT\nGoverning Board Member,\nFull Term', 0), ('CITY OF LA HABRA\nMember, City Council', 0), ('MUNICIPAL WATER DISTRICT OF ORANGE COUNTY\nDirector, Division 1, Short Term', 0), ('COSTA MESA SANITARY DISTRICT\nDirector, Division 2', 0), ('UNITED STATES REPRESENTATIVE\n46th District', 0), ('MEMBER OF THE STATE ASSEMBLY\n69th District', 0), ('NORTH ORANGE COUNTY COMMUNITY COLLEGE DISTRICT\nGoverning Board Member,\nTrustee Area 5', 0), ('CITY OF ANAHEIM\nMember, City Council, District 4', 0), ('SANTA ANA UNIFIED SCHOOL DI ...

# %%
# augment the sample
# reset the seed
seed = 123456
prng = SHA256(seed)
old_sample = cvr_sample
sample = sample_by_index(max_cards, new_size, prng=prng)
incremental_sample = np.sort(list(set(sample) - set(old_sample)))
n_phantom_sample = np.sum([cvr_list[i].phantom for i in incremental_sample])
print("The incremental sample includes {} phantom cards.".format(n_phantom_sample))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 5>()
#       3 seed = 123456
#       4 prng = SHA256(seed)
# ----> 5 old_sample = sample
#       6 sample = sample_by_index(max_cards, new_size, prng=prng)
#       7 incremental_sample = np.sort(list(set(sample) - set(old_sample)))
#
# NameError: name 'sample' is not defined

# %%
cvr_sample_lookup_new, cvr_sample_new, mvr_phantoms_sample_new = \
                sample_from_cvrs(cvr_list, manifest, incremental_sample)
write_cards_sampled(sample_file, cvr_sample_lookup_new, print_phantoms=False)
